# %%
# ドライブをマウント
from google.colab import drive
drive.mount('/content/drive')

# %%
cd /content/drive/My\ Drive/Transformer-master/
# Out:
# /content/drive/My Drive/Transformer

# %% [markdown]
# # ライブラリ読み込み

# %%
# !apt install aptitude
# !aptitude install mecab libmecab-dev mecab-ipadic-utf8 git make curl xz-utils file -y
# !pip install mecab-python3==0.6
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   aptitude-common libcgi-fast-perl libcgi-pm-perl libclass-accessor-perl
#   libcwidget3v5 libencode-locale-perl libfcgi-perl libhtml-parser-perl
#   libhtml-tagset-perl libhttp-date-perl libhttp-message-perl libio-html-perl
#   libio-string-perl liblwp-mediatypes-perl libparse-debianchangelog-perl
#   libsigc++-2.0-0v5 libsub-name-perl libtimedate-perl liburi-perl libxapian30
# Suggested packages:
#   aptitude-doc-en | aptitude-doc apt-xapian-index debtags tasksel
#   libcwidget-dev libdata-dump-perl libhtml-template-perl libxml-simple-perl
#   libwww-perl xapian-tools
# The following NEW packages will be installed:
#   aptitude aptitude-common libcgi-fast-perl libcgi-pm-perl
#   libclass-accessor-perl libcwidget3v5 libencode-locale-perl libfcgi-perl
#   libhtml-parser-perl libhtml-tagset-perl libhttp-date-perl
#   libhttp-message-perl libio-html-perl libio-string-perl
#   liblwp-mediatypes-perl libparse-debianchangelog-perl libsigc++-2.0-0v5
#   libsub-name-perl libtimedate-perl liburi-perl libxapian30
# 0 upgraded, 21 newly installed, 0 to remove and 35 not upgraded.
# Need to get 3,877 kB of archives.
# After this operation, 15.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 aptitude-common all 0.8.10-6ubuntu1 [1,014 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsigc++-2.0-0v5 amd64 2.10.0-2 [10.9 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcwidget3v5 amd64 0.5.17-7 [286 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxapian30 amd64 1.4.5-1ubuntu0.1 [631 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 aptitude amd64 0.8.10-6ubuntu1 [1,269 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhtml-tagset-perl all 3.20-3 [12.1 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 liburi-perl all 1.73-1 [77.2 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhtml-parser-perl amd64 3.72-3build1 [85.9 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcgi-pm-perl all 4.38-1 [185 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfcgi-perl amd64 0.78-2build1 [32.8 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcgi-fast-perl all 1:2.13-1 [9,940 B]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsub-name-perl amd64 0.21-1build1 [11.6 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 libclass-accessor-perl all 0.51-1 [21.2 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 libencode-locale-perl all 1.05-1 [12.3 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtimedate-perl all 2.3000-2 [37.5 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhttp-date-perl all 6.02-1 [10.4 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/main amd64 libio-html-perl all 1.001-1 [14.9 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 liblwp-mediatypes-perl all 6.02-1 [21.7 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhttp-message-perl all 6.14-1 [72.1 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic/main amd64 libio-string-perl all 1.08-3 [11.1 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/main amd64 libparse-debianchangelog-perl all 1.2.0-12 [49.5 kB]
# Fetched 3,877 kB in 1s (3,193 kB/s)
# Selecting previously unselected package aptitude-common.
# (Reading database ... 144487 files and directories currently installed.)
# Preparing to unpack .../00-aptitude-common_0.8.10-6ubuntu1_all.deb ...
# Unpacking aptitude-common (0.8.10-6ubuntu1) ...
# Selecting previously unselected package libsigc++-2.0-0v5:amd64.
# Preparing to unpack .../01-libsigc++-2.0-0v5_2.10.0-2_amd64.deb ...
# Unpacking libsigc++-2.0-0v5:amd64 (2.10.0-2) ...
# Selecting previously unselected package libcwidget3v5:amd64.
# Preparing to unpack .../02-libcwidget3v5_0.5.17-7_amd64.deb ...
# Unpacking libcwidget3v5:amd64 (0.5.17-7) ...
# Selecting previously unselected package libxapian30:amd64.
# Preparing to unpack .../03-libxapian30_1.4.5-1ubuntu0.1_amd64.deb ...
# Unpacking libxapian30:amd64 (1.4.5-1ubuntu0.1) ...
# Selecting previously unselected package aptitude.
# Preparing to unpack .../04-aptitude_0.8.10-6ubuntu1_amd64.deb ...
# Unpacking aptitude (0.8.10-6ubuntu1) ...
# Selecting previously unselected package libhtml-tagset-perl.
# Preparing to unpack .../05-libhtml-tagset-perl_3.20-3_all.deb ...
# Unpacking libhtml-tagset-perl (3.20-3) ...
# Selecting previously unselected package liburi-perl.
# Preparing to unpack .../06-liburi-perl_1.73-1_all.deb ...
# Unpacking liburi-perl (1.73-1) ...
# Selecting previously unselected package libhtml-parser-perl.
# Preparing to unpack .../07-libhtml-parser-perl_3.72-3build1_amd64.deb ...
# Unpacking libhtml-parser-perl (3.72-3build1) ...
# Selecting previously unselected package libcgi-pm-perl.
# Preparing to unpack .../08-libcgi-pm-perl_4.38-1_all.deb ...
# Unpacking libcgi-pm-perl (4.38-1) ...
# Selecting previously unselected package libfcgi-perl.
# Preparing to unpack .../09-libfcgi-perl_0.78-2build1_amd64.deb ...
# Unpacking libfcgi-perl (0.78-2build1) ...
# Selecting previously unselected package libcgi-fast-perl.
# Preparing to unpack .../10-libcgi-fast-perl_1%3a2.13-1_all.deb ...
# Unpacking libcgi-fast-perl (1:2.13-1) ...
# Selecting previously unselected package libsub-name-perl.
# Preparing to unpack .../11-libsub-name-perl_0.21-1build1_amd64.deb ...
# Unpacking libsub-name-perl (0.21-1build1) ...
# Selecting previously unselected package libclass-accessor-perl.
# Preparing to unpack .../12-libclass-accessor-perl_0.51-1_all.deb ...
# Unpacking libclass-accessor-perl (0.51-1) ...
# Selecting previously unselected package libencode-locale-perl.
# Preparing to unpack .../13-libencode-locale-perl_1.05-1_all.deb ...
# Unpacking libencode-locale-perl (1.05-1) ...
# Selecting previously unselected package libtimedate-perl.
# Preparing to unpack .../14-libtimedate-perl_2.3000-2_all.deb ...
# Unpacking libtimedate-perl (2.3000-2) ...
# Selecting previously unselected package libhttp-date-perl.
# Preparing to unpack .../15-libhttp-date-perl_6.02-1_all.deb ...
# Unpacking libhttp-date-perl (6.02-1) ...
# Selecting previously unselected package libio-html-perl.
# Preparing to unpack .../16-libio-html-perl_1.001-1_all.deb ...
# Unpacking libio-html-perl (1.001-1) ...
# Selecting previously unselected package liblwp-mediatypes-perl.
# Preparing to unpack .../17-liblwp-mediatypes-perl_6.02-1_all.deb ...
# Unpacking liblwp-mediatypes-perl (6.02-1) ...
# Selecting previously unselected package libhttp-message-perl.
# Preparing to unpack .../18-libhttp-message-perl_6.14-1_all.deb ...
# Unpacking libhttp-message-perl (6.14-1) ...
# Selecting previously unselected package libio-string-perl.
# Preparing to unpack .../19-libio-string-perl_1.08-3_all.deb ...
# Unpacking libio-string-perl (1.08-3) ...
# Selecting previously unselected package libparse-debianchangelog-perl.
# Preparing to unpack .../20-libparse-debianchangelog-perl_1.2.0-12_all.deb ...
# Unpacking libparse-debianchangelog-perl (1.2.0-12) ...
# Setting up libhtml-tagset-perl (3.20-3) ...
# Setting up libxapian30:amd64 (1.4.5-1ubuntu0.1) ...
# Setting up libencode-locale-perl (1.05-1) ...
# Setting up libtimedate-perl (2.3000-2) ...
# Setting up libio-html-perl (1.001-1) ...
# Setting up aptitude-common (0.8.10-6ubuntu1) ...
# Setting up liblwp-mediatypes-perl (6.02-1) ...
# Setting up liburi-perl (1.73-1) ...
# Setting up libhtml-parser-perl (3.72-3build1) ...
# Setting up libcgi-pm-perl (4.38-1) ...
# Setting up libio-string-perl (1.08-3) ...
# Setting up libsub-name-perl (0.21-1build1) ...
# Setting up libfcgi-perl (0.78-2build1) ...
# Setting up libsigc++-2.0-0v5:amd64 (2.10.0-2) ...
# Setting up libclass-accessor-perl (0.51-1) ...
# Setting up libhttp-date-perl (6.02-1) ...
# Setting up libcgi-fast-perl (1:2.13-1) ...
# Setting up libparse-debianchangelog-perl (1.2.0-12) ...
# Setting up libhttp-message-perl (6.14-1) ...
# Setting up libcwidget3v5:amd64 (0.5.17-7) ...
# Setting up aptitude (0.8.10-6ubuntu1) ...
# update-alternatives: using /usr/bin/aptitude-curses to provide /usr/bin/aptitude (aptitude) in auto mode
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# git is already installed at the requested version (1:2.17.1-1ubuntu0.7)
# make is already installed at the requested version (4.1-9.1ubuntu1)
# curl is already installed at the requested version (7.58.0-2ubuntu3.9)
# xz-utils is already installed at the requested version (5.2.2-1.3)
# git is already installed at the requested version (1:2.17.1-1ubuntu0.7)
# make is already installed at the requested version (4.1-9.1ubuntu1)
# curl is already installed at the requested version (7.58.0-2ubuntu3.9)
# xz-utils is already installed at the requested version (5.2.2-1.3)
# The following NEW packages will be installed:
#   file libmagic-mgc{a} libmagic1{a} libmecab-dev libmecab2{a} mecab mecab-ipadic{a} mecab-ipadic-utf8 mecab-jumandic{a} mecab-jumandic-utf8{a} mecab-utils{a}
# The following packages will be REMOVED:
#   libnvidia-common-440{u}
# 0 packages upgraded, 11 newly installed, 1 to remove and 35 not upgraded.
# Need to get 29.3 MB of archives. After unpacking 282 MB will be used.
# Get: 1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic-mgc amd64 1:5.32-2ubuntu0.4 [184 kB]
# Get: 2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic1 amd64 1:5.32-2ubuntu0.4 [68.6 kB]
# Get: 3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 file amd64 1:5.32-2ubuntu0.4 [22.1 kB]
# Get: 4 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libmecab2 amd64 0.996-5 [257 kB]
# Get: 5 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libmecab-dev amd64 0.996-5 [308 kB]
# Get: 6 http://archive.ubuntu.com/ubuntu bionic/universe amd64 mecab-utils amd64 0.996-5 [4,856 B]
# Get: 7 http://archive.ubuntu.com/ubuntu bionic/universe amd64 mecab-jumandic-utf8 all 7.0-20130310-4 [16.2 MB]
# Get: 8 http://archive.ubuntu.com/ubuntu bionic/universe amd64 mecab-jumandic all 7.0-20130310-4 [2,212 B]
# Get: 9 http://archive.ubuntu.com/ubuntu bionic/universe amd64 mecab-ipadic all 2.7.0-20070801+main-1 [12.1 MB]
# Get: 10 http://archive.ubuntu.com/ubuntu bionic/universe amd64 mecab amd64 0.996-5 [132 kB]
# Get: 11 http://archive.ubuntu.com/ubuntu bionic/universe amd64 mecab-ipadic-utf8 all 2.7.0-20070801+main-1 [3,522 B]
# Fetched 29.3 MB in 2s (14.0 MB/s)
# (Reading database ... 144946 files and directories currently installed.)
# Removing libnvidia-common-440 (440.100-0ubuntu0.18.04.1) ...
# Selecting previously unselected package libmagic-mgc.
# (Reading database ... 144941 files and directories currently installed.)
# Preparing to unpack .../00-libmagic-mgc_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libmagic1:amd64.
# Preparing to unpack .../01-libmagic1_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package file.
# Preparing to unpack .../02-file_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking file (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libmecab2:amd64.
# Preparing to unpack .../03-libmecab2_0.996-5_amd64.deb ...
# Unpacking libmecab2:amd64 (0.996-5) ...
# Selecting previously unselected package libmecab-dev.
# Preparing to unpack .../04-libmecab-dev_0.996-5_amd64.deb ...
# Unpacking libmecab-dev (0.996-5) ...
# Selecting previously unselected package mecab-utils.
# Preparing to unpack .../05-mecab-utils_0.996-5_amd64.deb ...
# Unpacking mecab-utils (0.996-5) ...
# Selecting previously unselected package mecab-jumandic-utf8.
# Preparing to unpack .../06-mecab-jumandic-utf8_7.0-20130310-4_all.deb ...
# Unpacking mecab-jumandic-utf8 (7.0-20130310-4) ...
# Selecting previously unselected package mecab-jumandic.
# Preparing to unpack .../07-mecab-jumandic_7.0-20130310-4_all.deb ...
# Unpacking mecab-jumandic (7.0-20130310-4) ...
# Selecting previously unselected package mecab-ipadic.
# Preparing to unpack .../08-mecab-ipadic_2.7.0-20070801+main-1_all.deb ...
# Unpacking mecab-ipadic (2.7.0-20070801+main-1) ...
# Selecting previously unselected package mecab.
# Preparing to unpack .../09-mecab_0.996-5_amd64.deb ...
# Unpacking mecab (0.996-5) ...
# Selecting previously unselected package mecab-ipadic-utf8.
# Preparing to unpack .../10-mecab-ipadic-utf8_2.7.0-20070801+main-1_all.deb ...
# Unpacking mecab-ipadic-utf8 (2.7.0-20070801+main-1) ...
# Setting up libmecab2:amd64 (0.996-5) ...
# Setting up libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Setting up libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Setting up mecab-utils (0.996-5) ...
# Setting up mecab-ipadic (2.7.0-20070801+main-1) ...
# Compiling IPA dictionary for Mecab.  This takes long time...
# reading /usr/share/mecab/dic/ipadic/unk.def ... 40
# emitting double-array: 100% |###########################################|
# /usr/share/mecab/dic/ipadic/model.def is not found. skipped.
# reading /usr/share/mecab/dic/ipadic/Prefix.csv ... 221
# reading /usr/share/mecab/dic/ipadic/Noun.name.csv ... 34202
# reading /usr/share/mecab/dic/ipadic/Adverb.csv ... 3032
# reading /usr/share/mecab/dic/ipadic/Noun.csv ... 60477
# reading /usr/share/mecab/dic/ipadic/Noun.org.csv ... 16668
# reading /usr/share/mecab/dic/ipadic/Conjunction.csv ... 171
# reading /usr/share/mecab/dic/ipadic/Verb.csv ... 130750
# reading /usr/share/mecab/dic/ipadic/Adj.csv ... 27210
# reading /usr/share/mecab/dic/ipadic/Noun.adjv.csv ... 3328
# reading /usr/share/mecab/dic/ipadic/Postp-col.csv ... 91
# reading /usr/share/mecab/dic/ipadic/Noun.verbal.csv ... 12146
# reading /usr/share/mecab/dic/ipadic/Noun.nai.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Noun.adverbal.csv ... 795
# reading /usr/share/mecab/dic/ipadic/Noun.demonst.csv ... 120
# reading /usr/share/mecab/dic/ipadic/Suffix.csv ... 1393
# reading /usr/share/mecab/dic/ipadic/Auxil.csv ... 199
# reading /usr/share/mecab/dic/ipadic/Noun.proper.csv ... 27327
# reading /usr/share/mecab/dic/ipadic/Noun.number.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Symbol.csv ... 208
# reading /usr/share/mecab/dic/ipadic/Interjection.csv ... 252
# reading /usr/share/mecab/dic/ipadic/Others.csv ... 2
# reading /usr/share/mecab/dic/ipadic/Filler.csv ... 19
# reading /usr/share/mecab/dic/ipadic/Adnominal.csv ... 135
# reading /usr/share/mecab/dic/ipadic/Postp.csv ... 146
# reading /usr/share/mecab/dic/ipadic/Noun.place.csv ... 72999
# reading /usr/share/mecab/dic/ipadic/Noun.others.csv ... 151
# emitting double-array: 100% |###########################################|
# reading /usr/share/mecab/dic/ipadic/matrix.def ... 1316x1316
# emitting matrix      : 100% |###########################################|
#
# done!
# update-alternatives: using /var/lib/mecab/dic/ipadic to provide /var/lib/mecab/dic/debian (mecab-dictionary) in auto mode
# Setting up libmecab-dev (0.996-5) ...
# Setting up file (1:5.32-2ubuntu0.4) ...
# Setting up mecab-jumandic-utf8 (7.0-20130310-4) ...
# Compiling Juman dictionary for Mecab.
# reading /usr/share/mecab/dic/juman/unk.def ... 37
# emitting double-array: 100% |###########################################|
# reading /usr/share/mecab/dic/juman/Prefix.csv ... 90
# reading /usr/share/mecab/dic/juman/Demonstrative.csv ... 97
# reading /usr/share/mecab/dic/juman/Noun.suusi.csv ... 49
# reading /usr/share/mecab/dic/juman/Emoticon.csv ... 972
# reading /usr/share/mecab/dic/juman/Noun.keishiki.csv ... 8
# reading /usr/share/mecab/dic/juman/ContentW.csv ... 551145
# reading /usr/share/mecab/dic/juman/Special.csv ... 158
# reading /usr/share/mecab/dic/juman/Auto.csv ... 18931
# reading /usr/share/mecab/dic/juman/AuxV.csv ... 593
# reading /usr/share/mecab/dic/juman/Noun.hukusi.csv ... 81
# reading /usr/share/mecab/dic/juman/Rengo.csv ... 1118
# reading /usr/share/mecab/dic/juman/Suffix.csv ... 2128
# reading /usr/share/mecab/dic/juman/Assert.csv ... 34
# reading /usr/share/mecab/dic/juman/Wikipedia.csv ... 167709
# reading /usr/share/mecab/dic/juman/Postp.csv ... 108
# reading /usr/share/mecab/dic/juman/Noun.koyuu.csv ... 7964
# emitting double-array: 100% |###########################################|
# reading /usr/share/mecab/dic/juman/matrix.def ... 1876x1876
# emitting matrix      : 100% |###########################################|
#
# done!
# Setting up mecab-ipadic-utf8 (2.7.0-20070801+main-1) ...
# Compiling IPA dictionary for Mecab.  This takes long time...
# reading /usr/share/mecab/dic/ipadic/unk.def ... 40
# emitting double-array: 100% |###########################################|
# /usr/share/mecab/dic/ipadic/model.def is not found. skipped.
# reading /usr/share/mecab/dic/ipadic/Prefix.csv ... 221
# reading /usr/share/mecab/dic/ipadic/Noun.name.csv ... 34202
# reading /usr/share/mecab/dic/ipadic/Adverb.csv ... 3032
# reading /usr/share/mecab/dic/ipadic/Noun.csv ... 60477
# reading /usr/share/mecab/dic/ipadic/Noun.org.csv ... 16668
# reading /usr/share/mecab/dic/ipadic/Conjunction.csv ... 171
# reading /usr/share/mecab/dic/ipadic/Verb.csv ... 130750
# reading /usr/share/mecab/dic/ipadic/Adj.csv ... 27210
# reading /usr/share/mecab/dic/ipadic/Noun.adjv.csv ... 3328
# reading /usr/share/mecab/dic/ipadic/Postp-col.csv ... 91
# reading /usr/share/mecab/dic/ipadic/Noun.verbal.csv ... 12146
# reading /usr/share/mecab/dic/ipadic/Noun.nai.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Noun.adverbal.csv ... 795
# reading /usr/share/mecab/dic/ipadic/Noun.demonst.csv ... 120
# reading /usr/share/mecab/dic/ipadic/Suffix.csv ... 1393
# reading /usr/share/mecab/dic/ipadic/Auxil.csv ... 199
# reading /usr/share/mecab/dic/ipadic/Noun.proper.csv ... 27327
# reading /usr/share/mecab/dic/ipadic/Noun.number.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Symbol.csv ... 208
# reading /usr/share/mecab/dic/ipadic/Interjection.csv ... 252
# reading /usr/share/mecab/dic/ipadic/Others.csv ... 2
# reading /usr/share/mecab/dic/ipadic/Filler.csv ... 19
# reading /usr/share/mecab/dic/ipadic/Adnominal.csv ... 135
# reading /usr/share/mecab/dic/ipadic/Postp.csv ... 146
# reading /usr/share/mecab/dic/ipadic/Noun.place.csv ... 72999
# reading /usr/share/mecab/dic/ipadic/Noun.others.csv ... 151
# emitting double-array: 100% |###########################################|
# reading /usr/share/mecab/dic/ipadic/matrix.def ... 1316x1316
# emitting matrix      : 100% |###########################################|
#
# done!
# update-alternatives: using /var/lib/mecab/dic/ipadic-utf8 to provide /var/lib/mecab/dic/debian (mecab-dictionary) in auto mode
# Setting up mecab (0.996-5) ...
# Compiling IPA dictionary for Mecab.  This takes long time...
# reading /usr/share/mecab/dic/ipadic/unk.def ... 40
# emitting double-array: 100% |###########################################|
# /usr/share/mecab/dic/ipadic/model.def is not found. skipped.
# reading /usr/share/mecab/dic/ipadic/Prefix.csv ... 221
# reading /usr/share/mecab/dic/ipadic/Noun.name.csv ... 34202
# reading /usr/share/mecab/dic/ipadic/Adverb.csv ... 3032
# reading /usr/share/mecab/dic/ipadic/Noun.csv ... 60477
# reading /usr/share/mecab/dic/ipadic/Noun.org.csv ... 16668
# reading /usr/share/mecab/dic/ipadic/Conjunction.csv ... 171
# reading /usr/share/mecab/dic/ipadic/Verb.csv ... 130750
# reading /usr/share/mecab/dic/ipadic/Adj.csv ... 27210
# reading /usr/share/mecab/dic/ipadic/Noun.adjv.csv ... 3328
# reading /usr/share/mecab/dic/ipadic/Postp-col.csv ... 91
# reading /usr/share/mecab/dic/ipadic/Noun.verbal.csv ... 12146
# reading /usr/share/mecab/dic/ipadic/Noun.nai.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Noun.adverbal.csv ... 795
# reading /usr/share/mecab/dic/ipadic/Noun.demonst.csv ... 120
# reading /usr/share/mecab/dic/ipadic/Suffix.csv ... 1393
# reading /usr/share/mecab/dic/ipadic/Auxil.csv ... 199
# reading /usr/share/mecab/dic/ipadic/Noun.proper.csv ... 27327
# reading /usr/share/mecab/dic/ipadic/Noun.number.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Symbol.csv ... 208
# reading /usr/share/mecab/dic/ipadic/Interjection.csv ... 252
# reading /usr/share/mecab/dic/ipadic/Others.csv ... 2
# reading /usr/share/mecab/dic/ipadic/Filler.csv ... 19
# reading /usr/share/mecab/dic/ipadic/Adnominal.csv ... 135
# reading /usr/share/mecab/dic/ipadic/Postp.csv ... 146
# reading /usr/share/mecab/dic/ipadic/Noun.place.csv ... 72999
# reading /usr/share/mecab/dic/ipadic/Noun.others.csv ... 151
# emitting double-array: 100% |###########################################|
# reading /usr/share/mecab/dic/ipadic/matrix.def ... 1316x1316
# emitting matrix      : 100% |###########################################|
#
# done!
# Setting up mecab-jumandic (7.0-20130310-4) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
#
# Collecting mecab-python3==0.6
#   Downloading https://files.pythonhosted.org/packages/e3/7f/f98371035a0171abf95f9893eabf915f8a3199d005fed3cd69cc122fed40/mecab-python3-0.6.tar.gz (41kB)
#      |████████████████████████████████| 51kB 2.4MB/s
# Building wheels for collected packages: mecab-python3
#   Building wheel for mecab-python3 (setup.py) ... done
#   Created wheel for mecab-python3: filename=mecab_python3-0.6-cp36-cp36m-linux_x86_64.whl size=155480 sha256=884521a9deb892e06cdca2852b3750223dba443405e25a653a9d614e9519ebe4
#   Stored in directory: /root/.cache/pip/wheels/4d/51/5b/987888cacaf8bb25982ef4569261f68debe85b7587c5563c79
# Successfully built mecab-python3
# Installing collected packages: mecab-python3
# Successfully installed mecab-python3-0.6

# %%
import numpy as np
import os
import time
import MeCab

import preprocess_utils
import model
import weight_utils

import tensorflow.keras as keras
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.3.0

# %% [markdown]
# # 日英翻訳データ ダウンロード

# %%
# !wget http://www.manythings.org/anki/jpn-eng.zip
# !unzip ./jpn-eng.zip

# %% [markdown]
# # データ読み込み

# %%
dataset = preprocess_utils.CreateData(
    corpus_path = './jpn.txt',
    do_shuffle=True,
    seed_value=100,
    split_percent=0.95 # 学習データの割合
)

train_source, train_target, test_source, test_target = dataset.split_data()

print('**** Amount of data ****')
print('train_source： ', len(train_source))
print('train_target： ', len(train_target))
print('test_source： ', len(test_source))
print('test_target： ', len(test_target))
print('\n')
print('**** Train data example ****')
print('Source Example： ', train_source[0])
print('Target Example： ', train_target[0])
print('\n')
print('**** Test data example ****')
print('Source Example： ', test_source[0])
print('Target Example： ', test_target[0])
# Out:
# **** Amount of data ****
# train_source：  50914
# train_target：  50914
# test_source：  2680
# test_target：  2680
#
#
# **** Train data example ****
# Source Example：  Tom loves spaghetti.
# Target Example：  トムはスパゲッティが大好きです。
#
#
# **** Test data example ****
# Source Example：  Being left alone, the boy didn't know what to do.
# Target Example：  ひとりぼっちにされて少年はどうしてよいかわからなかった。

# %% [markdown]
# # 前処理

# %%
BATCH_SIZE = 64 # バッチサイズ
MAX_LENGTH = 60 # シーケンスの長さ
USE_TPU = True # TPUを使うか
BUFFER_SIZE = 50000

# %%
train_dataset = preprocess_utils.PreprocessData(
    mecab = MeCab.Tagger("-Ochasen"),
    source_data = train_source,
    target_data = train_target,
    max_length = MAX_LENGTH,
    batch_size = BATCH_SIZE,
    test_flag = False,
    train_dataset = None,
)

train_dataset.preprocess_data()

# %% [markdown]
# # バッチ作成

# %%
if USE_TPU:
  tpu_grpc_url = "grpc://" + os.environ["COLAB_TPU_ADDR"]
  tpu_cluster_resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu_grpc_url)
  tf.config.experimental_connect_to_cluster(tpu_cluster_resolver)
  tf.tpu.experimental.initialize_tpu_system(tpu_cluster_resolver)    
  strategy = tf.distribute.experimental.TPUStrategy(tpu_cluster_resolver)

trainset = tf.data.Dataset.from_tensor_slices((train_dataset.source_vector, train_dataset.target_vector))
trainset = trainset.map(lambda source, target: (tf.cast(source, tf.int64), tf.cast(target, tf.int64))).shuffle(buffer_size=BUFFER_SIZE).batch(BATCH_SIZE).prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

if USE_TPU:
  trainset = strategy.experimental_distribute_dataset(trainset)
# Out:
# INFO:tensorflow:Initializing the TPU system: grpc://10.50.108.130:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.50.108.130:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use  the non experimental symbol `tf.distribute.TPUStrategy` instead.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)

# %% [markdown]
# # モデル定義

# %%
num_layers=4 # レイヤー数
d_model=64 # 中間層の次元数
num_heads=4 # Multi Head Attentionのヘッド数
dff=2048 # Feed Forward Networkの次元数
dropout_rate = 0.1 # ドロップアウト率

source_vocab_size = max(train_dataset.source_token.values()) + 1 # source文の語彙数
target_vocab_size = max(train_dataset.target_token.values()) + 1 # target文の語彙数

# %%
# 重み初期化
def initialize_weight(checkpoint_path, optimizer, transformer, max_length, batch_size, use_tpu=False):

  if os.path.exists(checkpoint_path+'.pkl'):
    if use_tpu:
      number_of_tpu_cores = tpu_cluster_resolver.num_accelerators()['TPU']
      initialize_source, initialize_target = [[1]*max_length]*number_of_tpu_cores, [[1]*max_length]*number_of_tpu_cores
      initialize_set = tf.data.Dataset.from_tensor_slices((initialize_source, initialize_target))
      initialize_set = initialize_set.map(lambda source, target: (tf.cast(source, tf.int64), tf.cast(target, tf.int64))
          ).shuffle(buffer_size=BUFFER_SIZE).batch(batch_size).prefetch(
              buffer_size=tf.data.experimental.AUTOTUNE
          )
      initialize_set = strategy.experimental_distribute_dataset(initialize_set)

      for inp, tar in initialize_set:
        distributed_train_on_batch(inp, tar)

    else:
      initialize_set = tf.ones([batch_size, max_length], tf.int64)
      train_step(initialize_set, initialize_set)
    
    try:
      weight_utils.load_weights_from_pickle(checkpoint_path, optimizer, transformer)
    except:
      print('Failed to load checkpoints.')

  else:
    print('No available checkpoints.')

# %% [markdown]
# # 学習実行

# %%
with strategy.scope():
  # Transformer
  transformer = model.Transformer(num_layers, d_model, num_heads, dff,
                            source_vocab_size, target_vocab_size, 
                            pe_input=source_vocab_size, 
                            pe_target=target_vocab_size,
                            rate=dropout_rate)

  # Learning Rate
  learning_rate = model.CustomSchedule(d_model)

  # Optimizer
  optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98, 
                                      epsilon=1e-9)

  # Loss
  loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')

  # Loss Function
  def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask
    return tf.reduce_mean(loss_)

  # Metrics
  train_loss = tf.keras.metrics.Mean(name='train_loss')
  train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='train_accuracy')

  # Checkpoint
  checkpoint_path = "/content/drive/My Drive/Transformer-master/checkpoints/tpu/model"


  def train_step(inp, tar):
    tar_inp = tar[:, :-1]
    tar_real = tar[:, 1:]
    
    enc_padding_mask, combined_mask, dec_padding_mask = model.create_masks(inp, tar_inp)
    
    with tf.GradientTape() as tape:
      predictions, _ = transformer(inp, tar_inp, 
                                  True, 
                                  enc_padding_mask, 
                                  combined_mask, 
                                  dec_padding_mask)
      loss = loss_function(tar_real, predictions)

    gradients = tape.gradient(loss, transformer.trainable_variables)    
    optimizer.apply_gradients(zip(gradients, transformer.trainable_variables))
    
    train_loss(loss)
    train_accuracy(tar_real, predictions)

  @tf.function
  def distributed_train_on_batch(X, y):
    per_replica_losses = strategy.experimental_run_v2(train_step, args=(X, y))
    return strategy.reduce(tf.distribute.ReduceOp.MEAN, per_replica_losses, axis=None)

  # Initialize Weight
  initialize_weight(checkpoint_path, optimizer, transformer, MAX_LENGTH, BATCH_SIZE, use_tpu=USE_TPU)

  EPOCHS = 30
  batch = 0

  for epoch in range(EPOCHS):
    start = time.time()
    
    train_loss.reset_states()
    train_accuracy.reset_states()
    
    for inp, tar in trainset:
      distributed_train_on_batch(inp, tar)
      
      if batch % 50 == 0:
        print ('Epoch {} Batch {} Loss {:.4f} Accuracy {:.4f}'.format(
            epoch + 1, batch, train_loss.result(), train_accuracy.result()))
        
      batch+=1
        
    if (epoch + 1) % 5 == 0:
      weight_utils.save_weights_as_pickle(checkpoint_path, optimizer, transformer)
      
    print ('Epoch {} Loss {:.4f} Accuracy {:.4f}'.format(epoch + 1, 
                                                  train_loss.result(), 
                                                  train_accuracy.result()))

    print ('Time taken for 1 epoch: {} secs\n'.format(time.time() - start))
# Out:
# No available checkpoints.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/multi_device_iterator_ops.py:601: get_next_as_optional (from tensorflow.python.data.ops.iterator_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Iterator.get_next_as_optional()` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/multi_device_iterator_ops.py:601: get_next_as_optional (from tensorflow.python.data.ops.iterator_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Iterator.get_next_as_optional()` instead.
# WARNING:tensorflow:From <ipython-input-10-ebebb88d92dd>:58: StrategyBase.experimental_run_v2 (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# renamed to `run`
# WARNING:tensorflow:From <ipython-input-10-ebebb88d92dd>:58: StrategyBase.experimental_run_v2 (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# renamed to `run`
# Epoch 1 Batch 0 Loss 1.7047 Accuracy 0.0000
# Epoch 1 Batch 50 Loss 1.7183 Accuracy 0.0029
# Epoch 1 Batch 100 Loss 1.7140 Accuracy 0.0096
# Epoch 1 Batch 150 Loss 1.6973 Accuracy 0.0121
# Epoch 1 Batch 200 Loss 1.6745 Accuracy 0.0133
# Epoch 1 Batch 250 Loss 1.6476 Accuracy 0.0141
# Epoch 1 Batch 300 Loss 1.6141 Accuracy 0.0155
# Epoch 1 Batch 350 Loss 1.5745 Accuracy 0.0167
# Epoch 1 Batch 400 Loss 1.5317 Accuracy 0.0175
# Epoch 1 Batch 450 Loss 1.4872 Accuracy 0.0181
# Epoch 1 Batch 500 Loss 1.4444 Accuracy 0.0188
# Epoch 1 Batch 550 Loss 1.4051 Accuracy 0.0199
# Epoch 1 Batch 600 Loss 1.3683 Accuracy 0.0213
# Epoch 1 Batch 650 Loss 1.3350 Accuracy 0.0232
# Epoch 1 Batch 700 Loss 1.3007 Accuracy 0.0251
# Epoch 1 Batch 750 Loss 1.2689 Accuracy 0.0270
# Epoch 1 Loss nan Accuracy 0.0285
# Time taken for 1 epoch: 154.76837348937988 secs
#
# Epoch 2 Batch 800 Loss 0.7455 Accuracy 0.0532
# Epoch 2 Batch 850 Loss 0.7636 Accuracy 0.0565
# Epoch 2 Batch 900 Loss 0.7516 Accuracy 0.0580
# Epoch 2 Batch 950 Loss 0.7457 Accuracy 0.0592
# Epoch 2 Batch 1000 Loss 0.7404 Accuracy 0.0605
# Epoch 2 Batch 1050 Loss 0.7328 Accuracy 0.0614
# Epoch 2 Batch 1100 Loss 0.7260 Accuracy 0.0623
# Epoch 2 Batch 1150 Loss 0.7219 Accuracy 0.0631
# Epoch 2 Batch 1200 Loss 0.7158 Accuracy 0.0639
# Epoch 2 Batch 1250 Loss 0.7111 Accuracy 0.0646
# Epoch 2 Batch 1300 Loss 0.7057 Accuracy 0.0653
# Epoch 2 Batch 1350 Loss 0.7013 Accuracy 0.0660
# Epoch 2 Batch 1400 Loss 0.6970 Accuracy 0.0666
# Epoch 2 Batch 1450 Loss 0.6935 Accuracy 0.0673
# Epoch 2 Batch 1500 Loss 0.6896 Accuracy 0.0678
# Epoch 2 Batch 1550 Loss 0.6866 Accuracy 0.0684
# Epoch 2 Loss nan Accuracy 0.0689
# Time taken for 1 epoch: 64.28263592720032 secs
#
# Epoch 3 Batch 1600 Loss 0.6044 Accuracy 0.0768
# Epoch 3 Batch 1650 Loss 0.6068 Accuracy 0.0782
# Epoch 3 Batch 1700 Loss 0.6044 Accuracy 0.0784
# Epoch 3 Batch 1750 Loss 0.6010 Accuracy 0.0788
# Epoch 3 Batch 1800 Loss 0.5991 Accuracy 0.0791
# Epoch 3 Batch 1850 Loss 0.6003 Accuracy 0.0795
# Epoch 3 Batch 1900 Loss 0.6002 Accuracy 0.0797
# Epoch 3 Batch 1950 Loss 0.5983 Accuracy 0.0797
# Epoch 3 Batch 2000 Loss 0.5967 Accuracy 0.0798
# Epoch 3 Batch 2050 Loss 0.5950 Accuracy 0.0801
# Epoch 3 Batch 2100 Loss 0.5943 Accuracy 0.0804
# Epoch 3 Batch 2150 Loss 0.5930 Accuracy 0.0806
# Epoch 3 Batch 2200 Loss 0.5914 Accuracy 0.0808
# Epoch 3 Batch 2250 Loss 0.5899 Accuracy 0.0811
# Epoch 3 Batch 2300 Loss 0.5883 Accuracy 0.0814
# Epoch 3 Batch 2350 Loss 0.5872 Accuracy 0.0816
# Epoch 3 Loss nan Accuracy 0.0818
# Time taken for 1 epoch: 64.76322746276855 secs
#
# Epoch 4 Batch 2400 Loss 0.5615 Accuracy 0.0886
# Epoch 4 Batch 2450 Loss 0.5485 Accuracy 0.0877
# Epoch 4 Batch 2500 Loss 0.5437 Accuracy 0.0879
# Epoch 4 Batch 2550 Loss 0.5396 Accuracy 0.0880
# Epoch 4 Batch 2600 Loss 0.5372 Accuracy 0.0880
# Epoch 4 Batch 2650 Loss 0.5361 Accuracy 0.0881
# Epoch 4 Batch 2700 Loss 0.5344 Accuracy 0.0884
# Epoch 4 Batch 2750 Loss 0.5333 Accuracy 0.0886
# Epoch 4 Batch 2800 Loss 0.5322 Accuracy 0.0888
# Epoch 4 Batch 2850 Loss 0.5303 Accuracy 0.0889
# Epoch 4 Batch 2900 Loss 0.5285 Accuracy 0.0891
# Epoch 4 Batch 2950 Loss 0.5264 Accuracy 0.0892
# Epoch 4 Batch 3000 Loss 0.5247 Accuracy 0.0893
# Epoch 4 Batch 3050 Loss 0.5234 Accuracy 0.0895
# Epoch 4 Batch 3100 Loss 0.5218 Accuracy 0.0895
# Epoch 4 Batch 3150 Loss 0.5206 Accuracy 0.0897
# Epoch 4 Loss nan Accuracy 0.0898
# Time taken for 1 epoch: 65.56175255775452 secs
#
# Epoch 5 Batch 3200 Loss 0.4703 Accuracy 0.0955
# Epoch 5 Batch 3250 Loss 0.4725 Accuracy 0.0957
# Epoch 5 Batch 3300 Loss 0.4686 Accuracy 0.0959
# Epoch 5 Batch 3350 Loss 0.4712 Accuracy 0.0961
# Epoch 5 Batch 3400 Loss 0.4705 Accuracy 0.0963
# Epoch 5 Batch 3450 Loss 0.4697 Accuracy 0.0963
# Epoch 5 Batch 3500 Loss 0.4692 Accuracy 0.0964
# Epoch 5 Batch 3550 Loss 0.4674 Accuracy 0.0966
# Epoch 5 Batch 3600 Loss 0.4678 Accuracy 0.0967
# Epoch 5 Batch 3650 Loss 0.4672 Accuracy 0.0968
# Epoch 5 Batch 3700 Loss 0.4667 Accuracy 0.0969
# Epoch 5 Batch 3750 Loss 0.4663 Accuracy 0.0970
# Epoch 5 Batch 3800 Loss 0.4651 Accuracy 0.0972
# Epoch 5 Batch 3850 Loss 0.4642 Accuracy 0.0972
# Epoch 5 Batch 3900 Loss 0.4634 Accuracy 0.0975
# Epoch 5 Batch 3950 Loss 0.4618 Accuracy 0.0975
# Save checkpoints
# Epoch 5 Loss nan Accuracy 0.0976
# Time taken for 1 epoch: 67.82112431526184 secs
#
# Epoch 6 Batch 4000 Loss 0.4283 Accuracy 0.1049
# Epoch 6 Batch 4050 Loss 0.4225 Accuracy 0.1038
# Epoch 6 Batch 4100 Loss 0.4145 Accuracy 0.1037
# Epoch 6 Batch 4150 Loss 0.4154 Accuracy 0.1034
# Epoch 6 Batch 4200 Loss 0.4160 Accuracy 0.1036
# Epoch 6 Batch 4250 Loss 0.4155 Accuracy 0.1034
# Epoch 6 Batch 4300 Loss 0.4164 Accuracy 0.1035
# Epoch 6 Batch 4350 Loss 0.4171 Accuracy 0.1035
# Epoch 6 Batch 4400 Loss 0.4159 Accuracy 0.1036
# Epoch 6 Batch 4450 Loss 0.4153 Accuracy 0.1036
# Epoch 6 Batch 4500 Loss 0.4143 Accuracy 0.1037
# Epoch 6 Batch 4550 Loss 0.4140 Accuracy 0.1039
# Epoch 6 Batch 4600 Loss 0.4141 Accuracy 0.1040
# Epoch 6 Batch 4650 Loss 0.4135 Accuracy 0.1041
# Epoch 6 Batch 4700 Loss 0.4126 Accuracy 0.1042
# Epoch 6 Batch 4750 Loss 0.4126 Accuracy 0.1043
# Epoch 6 Loss nan Accuracy 0.1044
# Time taken for 1 epoch: 66.41233611106873 secs
#
# Epoch 7 Batch 4800 Loss 0.3556 Accuracy 0.1111
# Epoch 7 Batch 4850 Loss 0.3674 Accuracy 0.1101
# Epoch 7 Batch 4900 Loss 0.3687 Accuracy 0.1098
# Epoch 7 Batch 4950 Loss 0.3672 Accuracy 0.1096
# Epoch 7 Batch 5000 Loss 0.3668 Accuracy 0.1097
# Epoch 7 Batch 5050 Loss 0.3673 Accuracy 0.1098
# Epoch 7 Batch 5100 Loss 0.3682 Accuracy 0.1098
# Epoch 7 Batch 5150 Loss 0.3688 Accuracy 0.1099
# Epoch 7 Batch 5200 Loss 0.3702 Accuracy 0.1101
# Epoch 7 Batch 5250 Loss 0.3709 Accuracy 0.1101
# Epoch 7 Batch 5300 Loss 0.3715 Accuracy 0.1101
# Epoch 7 Batch 5350 Loss 0.3720 Accuracy 0.1102
# Epoch 7 Batch 5400 Loss 0.3719 Accuracy 0.1101
# Epoch 7 Batch 5450 Loss 0.3724 Accuracy 0.1102
# Epoch 7 Batch 5500 Loss 0.3725 Accuracy 0.1102
# Epoch 7 Batch 5550 Loss 0.3727 Accuracy 0.1102
# Epoch 7 Loss nan Accuracy 0.1102
# Time taken for 1 epoch: 65.61905837059021 secs
#
# Epoch 8 Batch 5600 Loss 0.3314 Accuracy 0.1144
# Epoch 8 Batch 5650 Loss 0.3292 Accuracy 0.1153
# Epoch 8 Batch 5700 Loss 0.3315 Accuracy 0.1149
# Epoch 8 Batch 5750 Loss 0.3351 Accuracy 0.1147
# Epoch 8 Batch 5800 Loss 0.3349 Accuracy 0.1144
# Epoch 8 Batch 5850 Loss 0.3367 Accuracy 0.1144
# Epoch 8 Batch 5900 Loss 0.3371 Accuracy 0.1146
# Epoch 8 Batch 5950 Loss 0.3385 Accuracy 0.1145
# Epoch 8 Batch 6000 Loss 0.3405 Accuracy 0.1146
# Epoch 8 Batch 6050 Loss 0.3415 Accuracy 0.1144
# Epoch 8 Batch 6100 Loss 0.3431 Accuracy 0.1144
# Epoch 8 Batch 6150 Loss 0.3433 Accuracy 0.1145
# Epoch 8 Batch 6200 Loss 0.3442 Accuracy 0.1145
# Epoch 8 Batch 6250 Loss 0.3451 Accuracy 0.1144
# Epoch 8 Batch 6300 Loss 0.3453 Accuracy 0.1145
# Epoch 8 Batch 6350 Loss 0.3458 Accuracy 0.1145
# Epoch 8 Loss nan Accuracy 0.1145
# Time taken for 1 epoch: 65.80302929878235 secs
#
# Epoch 9 Batch 6400 Loss 0.3219 Accuracy 0.1187
# Epoch 9 Batch 6450 Loss 0.3187 Accuracy 0.1186
# Epoch 9 Batch 6500 Loss 0.3207 Accuracy 0.1188
# Epoch 9 Batch 6550 Loss 0.3207 Accuracy 0.1191
# Epoch 9 Batch 6600 Loss 0.3209 Accuracy 0.1188
# Epoch 9 Batch 6650 Loss 0.3211 Accuracy 0.1186
# Epoch 9 Batch 6700 Loss 0.3218 Accuracy 0.1186
# Epoch 9 Batch 6750 Loss 0.3228 Accuracy 0.1185
# Epoch 9 Batch 6800 Loss 0.3223 Accuracy 0.1184
# Epoch 9 Batch 6850 Loss 0.3233 Accuracy 0.1182
# Epoch 9 Batch 6900 Loss 0.3239 Accuracy 0.1181
# Epoch 9 Batch 6950 Loss 0.3237 Accuracy 0.1180
# Epoch 9 Batch 7000 Loss 0.3245 Accuracy 0.1178
# Epoch 9 Batch 7050 Loss 0.3253 Accuracy 0.1178
# Epoch 9 Batch 7100 Loss 0.3258 Accuracy 0.1177
# Epoch 9 Batch 7150 Loss 0.3259 Accuracy 0.1177
# Epoch 9 Loss nan Accuracy 0.1177
# Time taken for 1 epoch: 64.81634020805359 secs
#
# Epoch 10 Batch 7200 Loss 0.2881 Accuracy 0.1212
# Epoch 10 Batch 7250 Loss 0.2915 Accuracy 0.1214
# Epoch 10 Batch 7300 Loss 0.2926 Accuracy 0.1211
# Epoch 10 Batch 7350 Loss 0.2967 Accuracy 0.1211
# Epoch 10 Batch 7400 Loss 0.2982 Accuracy 0.1209
# Epoch 10 Batch 7450 Loss 0.2985 Accuracy 0.1208
# Epoch 10 Batch 7500 Loss 0.2995 Accuracy 0.1208
# Epoch 10 Batch 7550 Loss 0.3008 Accuracy 0.1206
# Epoch 10 Batch 7600 Loss 0.3030 Accuracy 0.1206
# Epoch 10 Batch 7650 Loss 0.3039 Accuracy 0.1205
# Epoch 10 Batch 7700 Loss 0.3049 Accuracy 0.1206
# Epoch 10 Batch 7750 Loss 0.3057 Accuracy 0.1206
# Epoch 10 Batch 7800 Loss 0.3072 Accuracy 0.1206
# Epoch 10 Batch 7850 Loss 0.3081 Accuracy 0.1205
# Epoch 10 Batch 7900 Loss 0.3089 Accuracy 0.1204
# Epoch 10 Batch 7950 Loss 0.3093 Accuracy 0.1204
# Save checkpoints
# Epoch 10 Loss nan Accuracy 0.1204
# Time taken for 1 epoch: 70.14095783233643 secs
#
# Epoch 11 Batch 8000 Loss 0.2757 Accuracy 0.1254
# Epoch 11 Batch 8050 Loss 0.2809 Accuracy 0.1249
# Epoch 11 Batch 8100 Loss 0.2813 Accuracy 0.1242
# Epoch 11 Batch 8150 Loss 0.2833 Accuracy 0.1243
# Epoch 11 Batch 8200 Loss 0.2848 Accuracy 0.1241
# Epoch 11 Batch 8250 Loss 0.2858 Accuracy 0.1237
# Epoch 11 Batch 8300 Loss 0.2867 Accuracy 0.1235
# Epoch 11 Batch 8350 Loss 0.2892 Accuracy 0.1234
# Epoch 11 Batch 8400 Loss 0.2897 Accuracy 0.1232
# Epoch 11 Batch 8450 Loss 0.2902 Accuracy 0.1232
# Epoch 11 Batch 8500 Loss 0.2922 Accuracy 0.1231
# Epoch 11 Batch 8550 Loss 0.2930 Accuracy 0.1230
# Epoch 11 Batch 8600 Loss 0.2939 Accuracy 0.1229
# Epoch 11 Batch 8650 Loss 0.2945 Accuracy 0.1228
# Epoch 11 Batch 8700 Loss 0.2952 Accuracy 0.1227
# Epoch 11 Batch 8750 Loss 0.2957 Accuracy 0.1226
# Epoch 11 Loss nan Accuracy 0.1226
# Time taken for 1 epoch: 65.85112738609314 secs
#
# Epoch 12 Batch 8800 Loss 0.2634 Accuracy 0.1260
# Epoch 12 Batch 8850 Loss 0.2665 Accuracy 0.1259
# Epoch 12 Batch 8900 Loss 0.2697 Accuracy 0.1260
# Epoch 12 Batch 8950 Loss 0.2706 Accuracy 0.1258
# Epoch 12 Batch 9000 Loss 0.2713 Accuracy 0.1256
# Epoch 12 Batch 9050 Loss 0.2728 Accuracy 0.1255
# Epoch 12 Batch 9100 Loss 0.2746 Accuracy 0.1256
# Epoch 12 Batch 9150 Loss 0.2756 Accuracy 0.1254
# Epoch 12 Batch 9200 Loss 0.2773 Accuracy 0.1254
# Epoch 12 Batch 9250 Loss 0.2786 Accuracy 0.1252
# Epoch 12 Batch 9300 Loss 0.2795 Accuracy 0.1249
# Epoch 12 Batch 9350 Loss 0.2805 Accuracy 0.1247
# Epoch 12 Batch 9400 Loss 0.2822 Accuracy 0.1247
# Epoch 12 Batch 9450 Loss 0.2826 Accuracy 0.1247
# Epoch 12 Batch 9500 Loss 0.2832 Accuracy 0.1246
# Epoch 12 Batch 9550 Loss 0.2836 Accuracy 0.1245
# Epoch 12 Loss nan Accuracy 0.1245
# Time taken for 1 epoch: 65.66520309448242 secs
#
# Epoch 13 Batch 9600 Loss 0.2543 Accuracy 0.1278
# Epoch 13 Batch 9650 Loss 0.2565 Accuracy 0.1279
# Epoch 13 Batch 9700 Loss 0.2591 Accuracy 0.1278
# Epoch 13 Batch 9750 Loss 0.2593 Accuracy 0.1273
# Epoch 13 Batch 9800 Loss 0.2593 Accuracy 0.1273
# Epoch 13 Batch 9850 Loss 0.2610 Accuracy 0.1271
# Epoch 13 Batch 9900 Loss 0.2623 Accuracy 0.1271
# Epoch 13 Batch 9950 Loss 0.2643 Accuracy 0.1269
# Epoch 13 Batch 10000 Loss 0.2662 Accuracy 0.1268
# Epoch 13 Batch 10050 Loss 0.2667 Accuracy 0.1268
# Epoch 13 Batch 10100 Loss 0.2683 Accuracy 0.1266
# Epoch 13 Batch 10150 Loss 0.2699 Accuracy 0.1266
# Epoch 13 Batch 10200 Loss 0.2711 Accuracy 0.1266
# Epoch 13 Batch 10250 Loss 0.2724 Accuracy 0.1265
# Epoch 13 Batch 10300 Loss 0.2735 Accuracy 0.1264
# Epoch 13 Loss nan Accuracy 0.1264
# Time taken for 1 epoch: 65.06660580635071 secs
#
# Epoch 14 Batch 10350 Loss 0.2302 Accuracy 0.1274
# Epoch 14 Batch 10400 Loss 0.2450 Accuracy 0.1288
# Epoch 14 Batch 10450 Loss 0.2510 Accuracy 0.1296
# Epoch 14 Batch 10500 Loss 0.2513 Accuracy 0.1297
# Epoch 14 Batch 10550 Loss 0.2531 Accuracy 0.1296
# Epoch 14 Batch 10600 Loss 0.2538 Accuracy 0.1293
# Epoch 14 Batch 10650 Loss 0.2544 Accuracy 0.1289
# Epoch 14 Batch 10700 Loss 0.2552 Accuracy 0.1287
# Epoch 14 Batch 10750 Loss 0.2569 Accuracy 0.1286
# Epoch 14 Batch 10800 Loss 0.2588 Accuracy 0.1287
# Epoch 14 Batch 10850 Loss 0.2600 Accuracy 0.1284
# Epoch 14 Batch 10900 Loss 0.2612 Accuracy 0.1283
# Epoch 14 Batch 10950 Loss 0.2628 Accuracy 0.1281
# Epoch 14 Batch 11000 Loss 0.2635 Accuracy 0.1281
# Epoch 14 Batch 11050 Loss 0.2643 Accuracy 0.1280
# Epoch 14 Batch 11100 Loss 0.2649 Accuracy 0.1279
# Epoch 14 Loss nan Accuracy 0.1278
# Time taken for 1 epoch: 65.9107518196106 secs
#
# Epoch 15 Batch 11150 Loss 0.2477 Accuracy 0.1328
# Epoch 15 Batch 11200 Loss 0.2403 Accuracy 0.1309
# Epoch 15 Batch 11250 Loss 0.2377 Accuracy 0.1300
# Epoch 15 Batch 11300 Loss 0.2393 Accuracy 0.1301
# Epoch 15 Batch 11350 Loss 0.2421 Accuracy 0.1301
# Epoch 15 Batch 11400 Loss 0.2441 Accuracy 0.1303
# Epoch 15 Batch 11450 Loss 0.2458 Accuracy 0.1300
# Epoch 15 Batch 11500 Loss 0.2471 Accuracy 0.1297
# Epoch 15 Batch 11550 Loss 0.2484 Accuracy 0.1295
# Epoch 15 Batch 11600 Loss 0.2501 Accuracy 0.1293
# Epoch 15 Batch 11650 Loss 0.2517 Accuracy 0.1293
# Epoch 15 Batch 11700 Loss 0.2534 Accuracy 0.1293
# Epoch 15 Batch 11750 Loss 0.2544 Accuracy 0.1292
# Epoch 15 Batch 11800 Loss 0.2556 Accuracy 0.1292
# Epoch 15 Batch 11850 Loss 0.2567 Accuracy 0.1293
# Epoch 15 Batch 11900 Loss 0.2574 Accuracy 0.1292
# Save checkpoints
# Epoch 15 Loss nan Accuracy 0.1291
# Time taken for 1 epoch: 69.04210186004639 secs
#
# Epoch 16 Batch 11950 Loss 0.2215 Accuracy 0.1298
# Epoch 16 Batch 12000 Loss 0.2287 Accuracy 0.1319
# Epoch 16 Batch 12050 Loss 0.2335 Accuracy 0.1323
# Epoch 16 Batch 12100 Loss 0.2345 Accuracy 0.1322
# Epoch 16 Batch 12150 Loss 0.2363 Accuracy 0.1317
# Epoch 16 Batch 12200 Loss 0.2391 Accuracy 0.1318
# Epoch 16 Batch 12250 Loss 0.2400 Accuracy 0.1317
# Epoch 16 Batch 12300 Loss 0.2415 Accuracy 0.1316
# Epoch 16 Batch 12350 Loss 0.2427 Accuracy 0.1315
# Epoch 16 Batch 12400 Loss 0.2442 Accuracy 0.1313
# Epoch 16 Batch 12450 Loss 0.2455 Accuracy 0.1312
# Epoch 16 Batch 12500 Loss 0.2469 Accuracy 0.1310
# Epoch 16 Batch 12550 Loss 0.2476 Accuracy 0.1308
# Epoch 16 Batch 12600 Loss 0.2488 Accuracy 0.1308
# Epoch 16 Batch 12650 Loss 0.2496 Accuracy 0.1307
# Epoch 16 Batch 12700 Loss 0.2506 Accuracy 0.1305
# Epoch 16 Loss nan Accuracy 0.1304
# Time taken for 1 epoch: 65.90832829475403 secs
#
# Epoch 17 Batch 12750 Loss 0.2221 Accuracy 0.1311
# Epoch 17 Batch 12800 Loss 0.2249 Accuracy 0.1329
# Epoch 17 Batch 12850 Loss 0.2288 Accuracy 0.1324
# Epoch 17 Batch 12900 Loss 0.2309 Accuracy 0.1329
# Epoch 17 Batch 12950 Loss 0.2329 Accuracy 0.1327
# Epoch 17 Batch 13000 Loss 0.2340 Accuracy 0.1324
# Epoch 17 Batch 13050 Loss 0.2360 Accuracy 0.1325
# Epoch 17 Batch 13100 Loss 0.2363 Accuracy 0.1323
# Epoch 17 Batch 13150 Loss 0.2367 Accuracy 0.1321
# Epoch 17 Batch 13200 Loss 0.2381 Accuracy 0.1319
# Epoch 17 Batch 13250 Loss 0.2392 Accuracy 0.1317
# Epoch 17 Batch 13300 Loss 0.2410 Accuracy 0.1317
# Epoch 17 Batch 13350 Loss 0.2422 Accuracy 0.1316
# Epoch 17 Batch 13400 Loss 0.2433 Accuracy 0.1315
# Epoch 17 Batch 13450 Loss 0.2438 Accuracy 0.1315
# Epoch 17 Batch 13500 Loss 0.2448 Accuracy 0.1314
# Epoch 17 Loss nan Accuracy 0.1313
# Time taken for 1 epoch: 65.00110960006714 secs
#
# Epoch 18 Batch 13550 Loss 0.2161 Accuracy 0.1328
# Epoch 18 Batch 13600 Loss 0.2178 Accuracy 0.1330
# Epoch 18 Batch 13650 Loss 0.2168 Accuracy 0.1331
# Epoch 18 Batch 13700 Loss 0.2199 Accuracy 0.1335
# Epoch 18 Batch 13750 Loss 0.2223 Accuracy 0.1333
# Epoch 18 Batch 13800 Loss 0.2239 Accuracy 0.1332
# Epoch 18 Batch 13850 Loss 0.2263 Accuracy 0.1332
# Epoch 18 Batch 13900 Loss 0.2287 Accuracy 0.1331
# Epoch 18 Batch 13950 Loss 0.2309 Accuracy 0.1329
# Epoch 18 Batch 14000 Loss 0.2334 Accuracy 0.1329
# Epoch 18 Batch 14050 Loss 0.2343 Accuracy 0.1328
# Epoch 18 Batch 14100 Loss 0.2353 Accuracy 0.1327
# Epoch 18 Batch 14150 Loss 0.2365 Accuracy 0.1326
# Epoch 18 Batch 14200 Loss 0.2374 Accuracy 0.1325
# Epoch 18 Batch 14250 Loss 0.2388 Accuracy 0.1325
# Epoch 18 Batch 14300 Loss 0.2396 Accuracy 0.1324
# Epoch 18 Loss nan Accuracy 0.1323
# Time taken for 1 epoch: 65.38152146339417 secs
#
# Epoch 19 Batch 14350 Loss 0.2155 Accuracy 0.1339
# Epoch 19 Batch 14400 Loss 0.2173 Accuracy 0.1350
# Epoch 19 Batch 14450 Loss 0.2196 Accuracy 0.1352
# Epoch 19 Batch 14500 Loss 0.2209 Accuracy 0.1348
# Epoch 19 Batch 14550 Loss 0.2233 Accuracy 0.1347
# Epoch 19 Batch 14600 Loss 0.2245 Accuracy 0.1342
# Epoch 19 Batch 14650 Loss 0.2256 Accuracy 0.1340
# Epoch 19 Batch 14700 Loss 0.2266 Accuracy 0.1337
# Epoch 19 Batch 14750 Loss 0.2283 Accuracy 0.1338
# Epoch 19 Batch 14800 Loss 0.2297 Accuracy 0.1337
# Epoch 19 Batch 14850 Loss 0.2310 Accuracy 0.1337
# Epoch 19 Batch 14900 Loss 0.2320 Accuracy 0.1336
# Epoch 19 Batch 14950 Loss 0.2326 Accuracy 0.1335
# Epoch 19 Batch 15000 Loss 0.2336 Accuracy 0.1334
# Epoch 19 Batch 15050 Loss 0.2345 Accuracy 0.1333
# Epoch 19 Batch 15100 Loss 0.2352 Accuracy 0.1332
# Epoch 19 Loss nan Accuracy 0.1332
# Time taken for 1 epoch: 66.49251365661621 secs
#
# Epoch 20 Batch 15150 Loss 0.2124 Accuracy 0.1345
# Epoch 20 Batch 15200 Loss 0.2115 Accuracy 0.1355
# Epoch 20 Batch 15250 Loss 0.2098 Accuracy 0.1351
# Epoch 20 Batch 15300 Loss 0.2111 Accuracy 0.1352
# Epoch 20 Batch 15350 Loss 0.2139 Accuracy 0.1350
# Epoch 20 Batch 15400 Loss 0.2166 Accuracy 0.1351
# Epoch 20 Batch 15450 Loss 0.2183 Accuracy 0.1350
# Epoch 20 Batch 15500 Loss 0.2199 Accuracy 0.1350
# Epoch 20 Batch 15550 Loss 0.2213 Accuracy 0.1348
# Epoch 20 Batch 15600 Loss 0.2229 Accuracy 0.1346
# Epoch 20 Batch 15650 Loss 0.2244 Accuracy 0.1345
# Epoch 20 Batch 15700 Loss 0.2258 Accuracy 0.1343
# Epoch 20 Batch 15750 Loss 0.2271 Accuracy 0.1342
# Epoch 20 Batch 15800 Loss 0.2284 Accuracy 0.1340
# Epoch 20 Batch 15850 Loss 0.2298 Accuracy 0.1339
# Epoch 20 Batch 15900 Loss 0.2309 Accuracy 0.1339
# Save checkpoints
# Epoch 20 Loss nan Accuracy 0.1339
# Time taken for 1 epoch: 68.07004261016846 secs
#
# Epoch 21 Batch 15950 Loss 0.2104 Accuracy 0.1384
# Epoch 21 Batch 16000 Loss 0.2102 Accuracy 0.1378
# Epoch 21 Batch 16050 Loss 0.2098 Accuracy 0.1374
# Epoch 21 Batch 16100 Loss 0.2118 Accuracy 0.1369
# Epoch 21 Batch 16150 Loss 0.2124 Accuracy 0.1363
# Epoch 21 Batch 16200 Loss 0.2138 Accuracy 0.1362
# Epoch 21 Batch 16250 Loss 0.2157 Accuracy 0.1361
# Epoch 21 Batch 16300 Loss 0.2168 Accuracy 0.1359
# Epoch 21 Batch 16350 Loss 0.2178 Accuracy 0.1358
# Epoch 21 Batch 16400 Loss 0.2193 Accuracy 0.1356
# Epoch 21 Batch 16450 Loss 0.2212 Accuracy 0.1354
# Epoch 21 Batch 16500 Loss 0.2220 Accuracy 0.1352
# Epoch 21 Batch 16550 Loss 0.2239 Accuracy 0.1352
# Epoch 21 Batch 16600 Loss 0.2252 Accuracy 0.1351
# Epoch 21 Batch 16650 Loss 0.2260 Accuracy 0.1349
# Epoch 21 Batch 16700 Loss 0.2265 Accuracy 0.1349
# Epoch 21 Loss nan Accuracy 0.1348
# Time taken for 1 epoch: 66.35269522666931 secs
#
# Epoch 22 Batch 16750 Loss 0.1984 Accuracy 0.1392
# Epoch 22 Batch 16800 Loss 0.2028 Accuracy 0.1381
# Epoch 22 Batch 16850 Loss 0.2076 Accuracy 0.1380
# Epoch 22 Batch 16900 Loss 0.2081 Accuracy 0.1377
# Epoch 22 Batch 16950 Loss 0.2090 Accuracy 0.1373
# Epoch 22 Batch 17000 Loss 0.2103 Accuracy 0.1368
# Epoch 22 Batch 17050 Loss 0.2130 Accuracy 0.1368
# Epoch 22 Batch 17100 Loss 0.2144 Accuracy 0.1364
# Epoch 22 Batch 17150 Loss 0.2158 Accuracy 0.1364
# Epoch 22 Batch 17200 Loss 0.2172 Accuracy 0.1363
# Epoch 22 Batch 17250 Loss 0.2185 Accuracy 0.1361
# Epoch 22 Batch 17300 Loss 0.2196 Accuracy 0.1360
# Epoch 22 Batch 17350 Loss 0.2206 Accuracy 0.1359
# Epoch 22 Batch 17400 Loss 0.2216 Accuracy 0.1358
# Epoch 22 Batch 17450 Loss 0.2223 Accuracy 0.1355
# Epoch 22 Batch 17500 Loss 0.2233 Accuracy 0.1354
# Epoch 22 Loss nan Accuracy 0.1354
# Time taken for 1 epoch: 65.41380071640015 secs
#
# Epoch 23 Batch 17550 Loss 0.1974 Accuracy 0.1401
# Epoch 23 Batch 17600 Loss 0.1991 Accuracy 0.1388
# Epoch 23 Batch 17650 Loss 0.2003 Accuracy 0.1388
# Epoch 23 Batch 17700 Loss 0.2035 Accuracy 0.1384
# Epoch 23 Batch 17750 Loss 0.2048 Accuracy 0.1379
# Epoch 23 Batch 17800 Loss 0.2073 Accuracy 0.1379
# Epoch 23 Batch 17850 Loss 0.2089 Accuracy 0.1378
# Epoch 23 Batch 17900 Loss 0.2105 Accuracy 0.1374
# Epoch 23 Batch 17950 Loss 0.2117 Accuracy 0.1371
# Epoch 23 Batch 18000 Loss 0.2127 Accuracy 0.1368
# Epoch 23 Batch 18050 Loss 0.2138 Accuracy 0.1366
# Epoch 23 Batch 18100 Loss 0.2150 Accuracy 0.1367
# Epoch 23 Batch 18150 Loss 0.2161 Accuracy 0.1365
# Epoch 23 Batch 18200 Loss 0.2173 Accuracy 0.1364
# Epoch 23 Batch 18250 Loss 0.2184 Accuracy 0.1362
# Epoch 23 Batch 18300 Loss 0.2194 Accuracy 0.1362
# Epoch 23 Loss nan Accuracy 0.1362
# Time taken for 1 epoch: 64.97900605201721 secs
#
# Epoch 24 Batch 18350 Loss 0.1942 Accuracy 0.1400
# Epoch 24 Batch 18400 Loss 0.1973 Accuracy 0.1390
# Epoch 24 Batch 18450 Loss 0.1994 Accuracy 0.1387
# Epoch 24 Batch 18500 Loss 0.2003 Accuracy 0.1382
# Epoch 24 Batch 18550 Loss 0.2029 Accuracy 0.1377
# Epoch 24 Batch 18600 Loss 0.2051 Accuracy 0.1374
# Epoch 24 Batch 18650 Loss 0.2074 Accuracy 0.1375
# Epoch 24 Batch 18700 Loss 0.2087 Accuracy 0.1372
# Epoch 24 Batch 18750 Loss 0.2102 Accuracy 0.1373
# Epoch 24 Batch 18800 Loss 0.2112 Accuracy 0.1373
# Epoch 24 Batch 18850 Loss 0.2123 Accuracy 0.1373
# Epoch 24 Batch 18900 Loss 0.2132 Accuracy 0.1371
# Epoch 24 Batch 18950 Loss 0.2143 Accuracy 0.1370
# Epoch 24 Batch 19000 Loss 0.2150 Accuracy 0.1370
# Epoch 24 Batch 19050 Loss 0.2157 Accuracy 0.1368
# Epoch 24 Batch 19100 Loss 0.2165 Accuracy 0.1368
# Epoch 24 Loss nan Accuracy 0.1368
# Time taken for 1 epoch: 66.35198950767517 secs
#
# Epoch 25 Batch 19150 Loss 0.1898 Accuracy 0.1396
# Epoch 25 Batch 19200 Loss 0.1928 Accuracy 0.1396
# Epoch 25 Batch 19250 Loss 0.1941 Accuracy 0.1392
# Epoch 25 Batch 19300 Loss 0.1970 Accuracy 0.1393
# Epoch 25 Batch 19350 Loss 0.1982 Accuracy 0.1388
# Epoch 25 Batch 19400 Loss 0.1998 Accuracy 0.1383
# Epoch 25 Batch 19450 Loss 0.2020 Accuracy 0.1385
# Epoch 25 Batch 19500 Loss 0.2026 Accuracy 0.1384
# Epoch 25 Batch 19550 Loss 0.2051 Accuracy 0.1383
# Epoch 25 Batch 19600 Loss 0.2069 Accuracy 0.1382
# Epoch 25 Batch 19650 Loss 0.2079 Accuracy 0.1381
# Epoch 25 Batch 19700 Loss 0.2093 Accuracy 0.1378
# Epoch 25 Batch 19750 Loss 0.2106 Accuracy 0.1377
# Epoch 25 Batch 19800 Loss 0.2116 Accuracy 0.1376
# Epoch 25 Batch 19850 Loss 0.2126 Accuracy 0.1375
# Save checkpoints
# Epoch 25 Loss nan Accuracy 0.1374
# Time taken for 1 epoch: 67.22119092941284 secs
#
# Epoch 26 Batch 19900 Loss 0.2092 Accuracy 0.1467
# Epoch 26 Batch 19950 Loss 0.1905 Accuracy 0.1401
# Epoch 26 Batch 20000 Loss 0.1922 Accuracy 0.1407
# Epoch 26 Batch 20050 Loss 0.1932 Accuracy 0.1401
# Epoch 26 Batch 20100 Loss 0.1959 Accuracy 0.1398
# Epoch 26 Batch 20150 Loss 0.1965 Accuracy 0.1394
# Epoch 26 Batch 20200 Loss 0.1986 Accuracy 0.1392
# Epoch 26 Batch 20250 Loss 0.2000 Accuracy 0.1391
# Epoch 26 Batch 20300 Loss 0.2018 Accuracy 0.1390
# Epoch 26 Batch 20350 Loss 0.2027 Accuracy 0.1386
# Epoch 26 Batch 20400 Loss 0.2042 Accuracy 0.1384
# Epoch 26 Batch 20450 Loss 0.2052 Accuracy 0.1384
# Epoch 26 Batch 20500 Loss 0.2063 Accuracy 0.1383
# Epoch 26 Batch 20550 Loss 0.2073 Accuracy 0.1382
# Epoch 26 Batch 20600 Loss 0.2088 Accuracy 0.1382
# Epoch 26 Batch 20650 Loss 0.2100 Accuracy 0.1381
# Epoch 26 Loss nan Accuracy 0.1380
# Time taken for 1 epoch: 65.64855813980103 secs
#
# Epoch 27 Batch 20700 Loss 0.1958 Accuracy 0.1473
# Epoch 27 Batch 20750 Loss 0.1881 Accuracy 0.1423
# Epoch 27 Batch 20800 Loss 0.1873 Accuracy 0.1405
# Epoch 27 Batch 20850 Loss 0.1898 Accuracy 0.1403
# Epoch 27 Batch 20900 Loss 0.1921 Accuracy 0.1402
# Epoch 27 Batch 20950 Loss 0.1942 Accuracy 0.1400
# Epoch 27 Batch 21000 Loss 0.1955 Accuracy 0.1401
# Epoch 27 Batch 21050 Loss 0.1974 Accuracy 0.1399
# Epoch 27 Batch 21100 Loss 0.1981 Accuracy 0.1395
# Epoch 27 Batch 21150 Loss 0.2004 Accuracy 0.1393
# Epoch 27 Batch 21200 Loss 0.2018 Accuracy 0.1392
# Epoch 27 Batch 21250 Loss 0.2027 Accuracy 0.1390
# Epoch 27 Batch 21300 Loss 0.2038 Accuracy 0.1388
# Epoch 27 Batch 21350 Loss 0.2046 Accuracy 0.1388
# Epoch 27 Batch 21400 Loss 0.2058 Accuracy 0.1387
# Epoch 27 Batch 21450 Loss 0.2069 Accuracy 0.1385
# Epoch 27 Loss nan Accuracy 0.1385
# Time taken for 1 epoch: 64.9635910987854 secs
#
# Epoch 28 Batch 21500 Loss 0.1666 Accuracy 0.1381
# Epoch 28 Batch 21550 Loss 0.1841 Accuracy 0.1410
# Epoch 28 Batch 21600 Loss 0.1870 Accuracy 0.1417
# Epoch 28 Batch 21650 Loss 0.1890 Accuracy 0.1411
# Epoch 28 Batch 21700 Loss 0.1905 Accuracy 0.1410
# Epoch 28 Batch 21750 Loss 0.1915 Accuracy 0.1407
# Epoch 28 Batch 21800 Loss 0.1932 Accuracy 0.1403
# Epoch 28 Batch 21850 Loss 0.1949 Accuracy 0.1401
# Epoch 28 Batch 21900 Loss 0.1965 Accuracy 0.1399
# Epoch 28 Batch 21950 Loss 0.1979 Accuracy 0.1397
# Epoch 28 Batch 22000 Loss 0.1990 Accuracy 0.1396
# Epoch 28 Batch 22050 Loss 0.2003 Accuracy 0.1395
# Epoch 28 Batch 22100 Loss 0.2016 Accuracy 0.1393
# Epoch 28 Batch 22150 Loss 0.2026 Accuracy 0.1391
# Epoch 28 Batch 22200 Loss 0.2042 Accuracy 0.1391
# Epoch 28 Batch 22250 Loss 0.2048 Accuracy 0.1390
# Epoch 28 Loss nan Accuracy 0.1390
# Time taken for 1 epoch: 65.25989580154419 secs
#
# Epoch 29 Batch 22300 Loss 0.1831 Accuracy 0.1423
# Epoch 29 Batch 22350 Loss 0.1837 Accuracy 0.1421
# Epoch 29 Batch 22400 Loss 0.1865 Accuracy 0.1417
# Epoch 29 Batch 22450 Loss 0.1877 Accuracy 0.1414
# Epoch 29 Batch 22500 Loss 0.1900 Accuracy 0.1413
# Epoch 29 Batch 22550 Loss 0.1917 Accuracy 0.1407
# Epoch 29 Batch 22600 Loss 0.1926 Accuracy 0.1406
# Epoch 29 Batch 22650 Loss 0.1935 Accuracy 0.1404
# Epoch 29 Batch 22700 Loss 0.1950 Accuracy 0.1403
# Epoch 29 Batch 22750 Loss 0.1957 Accuracy 0.1401
# Epoch 29 Batch 22800 Loss 0.1973 Accuracy 0.1400
# Epoch 29 Batch 22850 Loss 0.1983 Accuracy 0.1400
# Epoch 29 Batch 22900 Loss 0.1992 Accuracy 0.1398
# Epoch 29 Batch 22950 Loss 0.2000 Accuracy 0.1396
# Epoch 29 Batch 23000 Loss 0.2011 Accuracy 0.1396
# Epoch 29 Batch 23050 Loss 0.2019 Accuracy 0.1395
# Epoch 29 Loss nan Accuracy 0.1395
# Time taken for 1 epoch: 68.09512948989868 secs
#
# Epoch 30 Batch 23100 Loss 0.1786 Accuracy 0.1421
# Epoch 30 Batch 23150 Loss 0.1770 Accuracy 0.1411
# Epoch 30 Batch 23200 Loss 0.1787 Accuracy 0.1410
# Epoch 30 Batch 23250 Loss 0.1801 Accuracy 0.1411
# Epoch 30 Batch 23300 Loss 0.1842 Accuracy 0.1411
# Epoch 30 Batch 23350 Loss 0.1864 Accuracy 0.1411
# Epoch 30 Batch 23400 Loss 0.1883 Accuracy 0.1410
# Epoch 30 Batch 23450 Loss 0.1905 Accuracy 0.1411
# Epoch 30 Batch 23500 Loss 0.1922 Accuracy 0.1407
# Epoch 30 Batch 23550 Loss 0.1937 Accuracy 0.1405
# Epoch 30 Batch 23600 Loss 0.1950 Accuracy 0.1405
# Epoch 30 Batch 23650 Loss 0.1960 Accuracy 0.1405
# Epoch 30 Batch 23700 Loss 0.1974 Accuracy 0.1406
# Epoch 30 Batch 23750 Loss 0.1981 Accuracy 0.1403
# Epoch 30 Batch 23800 Loss 0.1992 Accuracy 0.1402
# Epoch 30 Batch 23850 Loss 0.2002 Accuracy 0.1401
# Save checkpoints
# Epoch 30 Loss nan Accuracy 0.1400
# Time taken for 1 epoch: 66.65992593765259 secs
