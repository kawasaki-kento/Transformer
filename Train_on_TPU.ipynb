# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd /content/drive/My\ Drive/Transformer-master/
# Out:
# /content/drive/My Drive/Transformer-master

# %% [markdown]
# # ライブラリ読み込み

# %%
# !apt install aptitude
# !aptitude install mecab libmecab-dev mecab-ipadic-utf8 git make curl xz-utils file -y
# !pip install mecab-python3==0.6
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   aptitude-common libcgi-fast-perl libcgi-pm-perl libclass-accessor-perl
#   libcwidget3v5 libencode-locale-perl libfcgi-perl libhtml-parser-perl
#   libhtml-tagset-perl libhttp-date-perl libhttp-message-perl libio-html-perl
#   libio-string-perl liblwp-mediatypes-perl libparse-debianchangelog-perl
#   libsigc++-2.0-0v5 libsub-name-perl libtimedate-perl liburi-perl libxapian30
# Suggested packages:
#   aptitude-doc-en | aptitude-doc apt-xapian-index debtags tasksel
#   libcwidget-dev libdata-dump-perl libhtml-template-perl libxml-simple-perl
#   libwww-perl xapian-tools
# The following NEW packages will be installed:
#   aptitude aptitude-common libcgi-fast-perl libcgi-pm-perl
#   libclass-accessor-perl libcwidget3v5 libencode-locale-perl libfcgi-perl
#   libhtml-parser-perl libhtml-tagset-perl libhttp-date-perl
#   libhttp-message-perl libio-html-perl libio-string-perl
#   liblwp-mediatypes-perl libparse-debianchangelog-perl libsigc++-2.0-0v5
#   libsub-name-perl libtimedate-perl liburi-perl libxapian30
# 0 upgraded, 21 newly installed, 0 to remove and 35 not upgraded.
# Need to get 3,877 kB of archives.
# After this operation, 15.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 aptitude-common all 0.8.10-6ubuntu1 [1,014 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsigc++-2.0-0v5 amd64 2.10.0-2 [10.9 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcwidget3v5 amd64 0.5.17-7 [286 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxapian30 amd64 1.4.5-1ubuntu0.1 [631 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 aptitude amd64 0.8.10-6ubuntu1 [1,269 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhtml-tagset-perl all 3.20-3 [12.1 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 liburi-perl all 1.73-1 [77.2 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhtml-parser-perl amd64 3.72-3build1 [85.9 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcgi-pm-perl all 4.38-1 [185 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfcgi-perl amd64 0.78-2build1 [32.8 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcgi-fast-perl all 1:2.13-1 [9,940 B]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsub-name-perl amd64 0.21-1build1 [11.6 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 libclass-accessor-perl all 0.51-1 [21.2 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 libencode-locale-perl all 1.05-1 [12.3 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtimedate-perl all 2.3000-2 [37.5 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhttp-date-perl all 6.02-1 [10.4 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/main amd64 libio-html-perl all 1.001-1 [14.9 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 liblwp-mediatypes-perl all 6.02-1 [21.7 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhttp-message-perl all 6.14-1 [72.1 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic/main amd64 libio-string-perl all 1.08-3 [11.1 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/main amd64 libparse-debianchangelog-perl all 1.2.0-12 [49.5 kB]
# Fetched 3,877 kB in 1s (3,165 kB/s)
# Selecting previously unselected package aptitude-common.
# (Reading database ... 144556 files and directories currently installed.)
# Preparing to unpack .../00-aptitude-common_0.8.10-6ubuntu1_all.deb ...
# Unpacking aptitude-common (0.8.10-6ubuntu1) ...
# Selecting previously unselected package libsigc++-2.0-0v5:amd64.
# Preparing to unpack .../01-libsigc++-2.0-0v5_2.10.0-2_amd64.deb ...
# Unpacking libsigc++-2.0-0v5:amd64 (2.10.0-2) ...
# Selecting previously unselected package libcwidget3v5:amd64.
# Preparing to unpack .../02-libcwidget3v5_0.5.17-7_amd64.deb ...
# Unpacking libcwidget3v5:amd64 (0.5.17-7) ...
# Selecting previously unselected package libxapian30:amd64.
# Preparing to unpack .../03-libxapian30_1.4.5-1ubuntu0.1_amd64.deb ...
# Unpacking libxapian30:amd64 (1.4.5-1ubuntu0.1) ...
# Selecting previously unselected package aptitude.
# Preparing to unpack .../04-aptitude_0.8.10-6ubuntu1_amd64.deb ...
# Unpacking aptitude (0.8.10-6ubuntu1) ...
# Selecting previously unselected package libhtml-tagset-perl.
# Preparing to unpack .../05-libhtml-tagset-perl_3.20-3_all.deb ...
# Unpacking libhtml-tagset-perl (3.20-3) ...
# Selecting previously unselected package liburi-perl.
# Preparing to unpack .../06-liburi-perl_1.73-1_all.deb ...
# Unpacking liburi-perl (1.73-1) ...
# Selecting previously unselected package libhtml-parser-perl.
# Preparing to unpack .../07-libhtml-parser-perl_3.72-3build1_amd64.deb ...
# Unpacking libhtml-parser-perl (3.72-3build1) ...
# Selecting previously unselected package libcgi-pm-perl.
# Preparing to unpack .../08-libcgi-pm-perl_4.38-1_all.deb ...
# Unpacking libcgi-pm-perl (4.38-1) ...
# Selecting previously unselected package libfcgi-perl.
# Preparing to unpack .../09-libfcgi-perl_0.78-2build1_amd64.deb ...
# Unpacking libfcgi-perl (0.78-2build1) ...
# Selecting previously unselected package libcgi-fast-perl.
# Preparing to unpack .../10-libcgi-fast-perl_1%3a2.13-1_all.deb ...
# Unpacking libcgi-fast-perl (1:2.13-1) ...
# Selecting previously unselected package libsub-name-perl.
# Preparing to unpack .../11-libsub-name-perl_0.21-1build1_amd64.deb ...
# Unpacking libsub-name-perl (0.21-1build1) ...
# Selecting previously unselected package libclass-accessor-perl.
# Preparing to unpack .../12-libclass-accessor-perl_0.51-1_all.deb ...
# Unpacking libclass-accessor-perl (0.51-1) ...
# Selecting previously unselected package libencode-locale-perl.
# Preparing to unpack .../13-libencode-locale-perl_1.05-1_all.deb ...
# Unpacking libencode-locale-perl (1.05-1) ...
# Selecting previously unselected package libtimedate-perl.
# Preparing to unpack .../14-libtimedate-perl_2.3000-2_all.deb ...
# Unpacking libtimedate-perl (2.3000-2) ...
# Selecting previously unselected package libhttp-date-perl.
# Preparing to unpack .../15-libhttp-date-perl_6.02-1_all.deb ...
# Unpacking libhttp-date-perl (6.02-1) ...
# Selecting previously unselected package libio-html-perl.
# Preparing to unpack .../16-libio-html-perl_1.001-1_all.deb ...
# Unpacking libio-html-perl (1.001-1) ...
# Selecting previously unselected package liblwp-mediatypes-perl.
# Preparing to unpack .../17-liblwp-mediatypes-perl_6.02-1_all.deb ...
# Unpacking liblwp-mediatypes-perl (6.02-1) ...
# Selecting previously unselected package libhttp-message-perl.
# Preparing to unpack .../18-libhttp-message-perl_6.14-1_all.deb ...
# Unpacking libhttp-message-perl (6.14-1) ...
# Selecting previously unselected package libio-string-perl.
# Preparing to unpack .../19-libio-string-perl_1.08-3_all.deb ...
# Unpacking libio-string-perl (1.08-3) ...
# Selecting previously unselected package libparse-debianchangelog-perl.
# Preparing to unpack .../20-libparse-debianchangelog-perl_1.2.0-12_all.deb ...
# Unpacking libparse-debianchangelog-perl (1.2.0-12) ...
# Setting up libhtml-tagset-perl (3.20-3) ...
# Setting up libxapian30:amd64 (1.4.5-1ubuntu0.1) ...
# Setting up libencode-locale-perl (1.05-1) ...
# Setting up libtimedate-perl (2.3000-2) ...
# Setting up libio-html-perl (1.001-1) ...
# Setting up aptitude-common (0.8.10-6ubuntu1) ...
# Setting up liblwp-mediatypes-perl (6.02-1) ...
# Setting up liburi-perl (1.73-1) ...
# Setting up libhtml-parser-perl (3.72-3build1) ...
# Setting up libcgi-pm-perl (4.38-1) ...
# Setting up libio-string-perl (1.08-3) ...
# Setting up libsub-name-perl (0.21-1build1) ...
# Setting up libfcgi-perl (0.78-2build1) ...
# Setting up libsigc++-2.0-0v5:amd64 (2.10.0-2) ...
# Setting up libclass-accessor-perl (0.51-1) ...
# Setting up libhttp-date-perl (6.02-1) ...
# Setting up libcgi-fast-perl (1:2.13-1) ...
# Setting up libparse-debianchangelog-perl (1.2.0-12) ...
# Setting up libhttp-message-perl (6.14-1) ...
# Setting up libcwidget3v5:amd64 (0.5.17-7) ...
# Setting up aptitude (0.8.10-6ubuntu1) ...
# update-alternatives: using /usr/bin/aptitude-curses to provide /usr/bin/aptitude (aptitude) in auto mode
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# git is already installed at the requested version (1:2.17.1-1ubuntu0.7)
# make is already installed at the requested version (4.1-9.1ubuntu1)
# curl is already installed at the requested version (7.58.0-2ubuntu3.10)
# xz-utils is already installed at the requested version (5.2.2-1.3)
# git is already installed at the requested version (1:2.17.1-1ubuntu0.7)
# make is already installed at the requested version (4.1-9.1ubuntu1)
# curl is already installed at the requested version (7.58.0-2ubuntu3.10)
# xz-utils is already installed at the requested version (5.2.2-1.3)
# The following NEW packages will be installed:
#   file libmagic-mgc{a} libmagic1{a} libmecab-dev libmecab2{a} mecab mecab-ipadic{a} mecab-ipadic-utf8 mecab-jumandic{a} mecab-jumandic-utf8{a} mecab-utils{a}
# The following packages will be REMOVED:
#   libnvidia-common-440{u}
# 0 packages upgraded, 11 newly installed, 1 to remove and 35 not upgraded.
# Need to get 29.3 MB of archives. After unpacking 282 MB will be used.
# Get: 1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic-mgc amd64 1:5.32-2ubuntu0.4 [184 kB]
# Get: 2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic1 amd64 1:5.32-2ubuntu0.4 [68.6 kB]
# Get: 3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 file amd64 1:5.32-2ubuntu0.4 [22.1 kB]
# Get: 4 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libmecab2 amd64 0.996-5 [257 kB]
# Get: 5 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libmecab-dev amd64 0.996-5 [308 kB]
# Get: 6 http://archive.ubuntu.com/ubuntu bionic/universe amd64 mecab-utils amd64 0.996-5 [4,856 B]
# Get: 7 http://archive.ubuntu.com/ubuntu bionic/universe amd64 mecab-jumandic-utf8 all 7.0-20130310-4 [16.2 MB]
# Get: 8 http://archive.ubuntu.com/ubuntu bionic/universe amd64 mecab-jumandic all 7.0-20130310-4 [2,212 B]
# Get: 9 http://archive.ubuntu.com/ubuntu bionic/universe amd64 mecab-ipadic all 2.7.0-20070801+main-1 [12.1 MB]
# Get: 10 http://archive.ubuntu.com/ubuntu bionic/universe amd64 mecab amd64 0.996-5 [132 kB]
# Get: 11 http://archive.ubuntu.com/ubuntu bionic/universe amd64 mecab-ipadic-utf8 all 2.7.0-20070801+main-1 [3,522 B]
# Fetched 29.3 MB in 2s (15.3 MB/s)
# (Reading database ... 145015 files and directories currently installed.)
# Removing libnvidia-common-440 (440.100-0ubuntu0.18.04.1) ...
# Selecting previously unselected package libmagic-mgc.
# (Reading database ... 145010 files and directories currently installed.)
# Preparing to unpack .../00-libmagic-mgc_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libmagic1:amd64.
# Preparing to unpack .../01-libmagic1_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package file.
# Preparing to unpack .../02-file_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking file (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libmecab2:amd64.
# Preparing to unpack .../03-libmecab2_0.996-5_amd64.deb ...
# Unpacking libmecab2:amd64 (0.996-5) ...
# Selecting previously unselected package libmecab-dev.
# Preparing to unpack .../04-libmecab-dev_0.996-5_amd64.deb ...
# Unpacking libmecab-dev (0.996-5) ...
# Selecting previously unselected package mecab-utils.
# Preparing to unpack .../05-mecab-utils_0.996-5_amd64.deb ...
# Unpacking mecab-utils (0.996-5) ...
# Selecting previously unselected package mecab-jumandic-utf8.
# Preparing to unpack .../06-mecab-jumandic-utf8_7.0-20130310-4_all.deb ...
# Unpacking mecab-jumandic-utf8 (7.0-20130310-4) ...
# Selecting previously unselected package mecab-jumandic.
# Preparing to unpack .../07-mecab-jumandic_7.0-20130310-4_all.deb ...
# Unpacking mecab-jumandic (7.0-20130310-4) ...
# Selecting previously unselected package mecab-ipadic.
# Preparing to unpack .../08-mecab-ipadic_2.7.0-20070801+main-1_all.deb ...
# Unpacking mecab-ipadic (2.7.0-20070801+main-1) ...
# Selecting previously unselected package mecab.
# Preparing to unpack .../09-mecab_0.996-5_amd64.deb ...
# Unpacking mecab (0.996-5) ...
# Selecting previously unselected package mecab-ipadic-utf8.
# Preparing to unpack .../10-mecab-ipadic-utf8_2.7.0-20070801+main-1_all.deb ...
# Unpacking mecab-ipadic-utf8 (2.7.0-20070801+main-1) ...
# Setting up libmecab2:amd64 (0.996-5) ...
# Setting up libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Setting up libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Setting up mecab-utils (0.996-5) ...
# Setting up mecab-ipadic (2.7.0-20070801+main-1) ...
# Compiling IPA dictionary for Mecab.  This takes long time...
# reading /usr/share/mecab/dic/ipadic/unk.def ... 40
# emitting double-array: 100% |###########################################|
# /usr/share/mecab/dic/ipadic/model.def is not found. skipped.
# reading /usr/share/mecab/dic/ipadic/Noun.adjv.csv ... 3328
# reading /usr/share/mecab/dic/ipadic/Auxil.csv ... 199
# reading /usr/share/mecab/dic/ipadic/Noun.name.csv ... 34202
# reading /usr/share/mecab/dic/ipadic/Filler.csv ... 19
# reading /usr/share/mecab/dic/ipadic/Conjunction.csv ... 171
# reading /usr/share/mecab/dic/ipadic/Others.csv ... 2
# reading /usr/share/mecab/dic/ipadic/Suffix.csv ... 1393
# reading /usr/share/mecab/dic/ipadic/Noun.number.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Noun.place.csv ... 72999
# reading /usr/share/mecab/dic/ipadic/Noun.adverbal.csv ... 795
# reading /usr/share/mecab/dic/ipadic/Noun.org.csv ... 16668
# reading /usr/share/mecab/dic/ipadic/Noun.csv ... 60477
# reading /usr/share/mecab/dic/ipadic/Adnominal.csv ... 135
# reading /usr/share/mecab/dic/ipadic/Symbol.csv ... 208
# reading /usr/share/mecab/dic/ipadic/Adverb.csv ... 3032
# reading /usr/share/mecab/dic/ipadic/Noun.proper.csv ... 27327
# reading /usr/share/mecab/dic/ipadic/Postp-col.csv ... 91
# reading /usr/share/mecab/dic/ipadic/Adj.csv ... 27210
# reading /usr/share/mecab/dic/ipadic/Prefix.csv ... 221
# reading /usr/share/mecab/dic/ipadic/Noun.nai.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Noun.demonst.csv ... 120
# reading /usr/share/mecab/dic/ipadic/Noun.verbal.csv ... 12146
# reading /usr/share/mecab/dic/ipadic/Verb.csv ... 130750
# reading /usr/share/mecab/dic/ipadic/Noun.others.csv ... 151
# reading /usr/share/mecab/dic/ipadic/Postp.csv ... 146
# reading /usr/share/mecab/dic/ipadic/Interjection.csv ... 252
# emitting double-array: 100% |###########################################|
# reading /usr/share/mecab/dic/ipadic/matrix.def ... 1316x1316
# emitting matrix      : 100% |###########################################|
#
# done!
# update-alternatives: using /var/lib/mecab/dic/ipadic to provide /var/lib/mecab/dic/debian (mecab-dictionary) in auto mode
# Setting up libmecab-dev (0.996-5) ...
# Setting up file (1:5.32-2ubuntu0.4) ...
# Setting up mecab-jumandic-utf8 (7.0-20130310-4) ...
# Compiling Juman dictionary for Mecab.
# reading /usr/share/mecab/dic/juman/unk.def ... 37
# emitting double-array: 100% |###########################################|
# reading /usr/share/mecab/dic/juman/Noun.hukusi.csv ... 81
# reading /usr/share/mecab/dic/juman/Suffix.csv ... 2128
# reading /usr/share/mecab/dic/juman/Assert.csv ... 34
# reading /usr/share/mecab/dic/juman/Rengo.csv ... 1118
# reading /usr/share/mecab/dic/juman/Auto.csv ... 18931
# reading /usr/share/mecab/dic/juman/Wikipedia.csv ... 167709
# reading /usr/share/mecab/dic/juman/Noun.keishiki.csv ... 8
# reading /usr/share/mecab/dic/juman/Prefix.csv ... 90
# reading /usr/share/mecab/dic/juman/ContentW.csv ... 551145
# reading /usr/share/mecab/dic/juman/Emoticon.csv ... 972
# reading /usr/share/mecab/dic/juman/Noun.suusi.csv ... 49
# reading /usr/share/mecab/dic/juman/Noun.koyuu.csv ... 7964
# reading /usr/share/mecab/dic/juman/Demonstrative.csv ... 97
# reading /usr/share/mecab/dic/juman/AuxV.csv ... 593
# reading /usr/share/mecab/dic/juman/Postp.csv ... 108
# reading /usr/share/mecab/dic/juman/Special.csv ... 158
# emitting double-array: 100% |###########################################|
# reading /usr/share/mecab/dic/juman/matrix.def ... 1876x1876
# emitting matrix      : 100% |###########################################|
#
# done!
# Setting up mecab-ipadic-utf8 (2.7.0-20070801+main-1) ...
# Compiling IPA dictionary for Mecab.  This takes long time...
# reading /usr/share/mecab/dic/ipadic/unk.def ... 40
# emitting double-array: 100% |###########################################|
# /usr/share/mecab/dic/ipadic/model.def is not found. skipped.
# reading /usr/share/mecab/dic/ipadic/Noun.adjv.csv ... 3328
# reading /usr/share/mecab/dic/ipadic/Auxil.csv ... 199
# reading /usr/share/mecab/dic/ipadic/Noun.name.csv ... 34202
# reading /usr/share/mecab/dic/ipadic/Filler.csv ... 19
# reading /usr/share/mecab/dic/ipadic/Conjunction.csv ... 171
# reading /usr/share/mecab/dic/ipadic/Others.csv ... 2
# reading /usr/share/mecab/dic/ipadic/Suffix.csv ... 1393
# reading /usr/share/mecab/dic/ipadic/Noun.number.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Noun.place.csv ... 72999
# reading /usr/share/mecab/dic/ipadic/Noun.adverbal.csv ... 795
# reading /usr/share/mecab/dic/ipadic/Noun.org.csv ... 16668
# reading /usr/share/mecab/dic/ipadic/Noun.csv ... 60477
# reading /usr/share/mecab/dic/ipadic/Adnominal.csv ... 135
# reading /usr/share/mecab/dic/ipadic/Symbol.csv ... 208
# reading /usr/share/mecab/dic/ipadic/Adverb.csv ... 3032
# reading /usr/share/mecab/dic/ipadic/Noun.proper.csv ... 27327
# reading /usr/share/mecab/dic/ipadic/Postp-col.csv ... 91
# reading /usr/share/mecab/dic/ipadic/Adj.csv ... 27210
# reading /usr/share/mecab/dic/ipadic/Prefix.csv ... 221
# reading /usr/share/mecab/dic/ipadic/Noun.nai.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Noun.demonst.csv ... 120
# reading /usr/share/mecab/dic/ipadic/Noun.verbal.csv ... 12146
# reading /usr/share/mecab/dic/ipadic/Verb.csv ... 130750
# reading /usr/share/mecab/dic/ipadic/Noun.others.csv ... 151
# reading /usr/share/mecab/dic/ipadic/Postp.csv ... 146
# reading /usr/share/mecab/dic/ipadic/Interjection.csv ... 252
# emitting double-array: 100% |###########################################|
# reading /usr/share/mecab/dic/ipadic/matrix.def ... 1316x1316
# emitting matrix      : 100% |###########################################|
#
# done!
# update-alternatives: using /var/lib/mecab/dic/ipadic-utf8 to provide /var/lib/mecab/dic/debian (mecab-dictionary) in auto mode
# Setting up mecab (0.996-5) ...
# Compiling IPA dictionary for Mecab.  This takes long time...
# reading /usr/share/mecab/dic/ipadic/unk.def ... 40
# emitting double-array: 100% |###########################################|
# /usr/share/mecab/dic/ipadic/model.def is not found. skipped.
# reading /usr/share/mecab/dic/ipadic/Noun.adjv.csv ... 3328
# reading /usr/share/mecab/dic/ipadic/Auxil.csv ... 199
# reading /usr/share/mecab/dic/ipadic/Noun.name.csv ... 34202
# reading /usr/share/mecab/dic/ipadic/Filler.csv ... 19
# reading /usr/share/mecab/dic/ipadic/Conjunction.csv ... 171
# reading /usr/share/mecab/dic/ipadic/Others.csv ... 2
# reading /usr/share/mecab/dic/ipadic/Suffix.csv ... 1393
# reading /usr/share/mecab/dic/ipadic/Noun.number.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Noun.place.csv ... 72999
# reading /usr/share/mecab/dic/ipadic/Noun.adverbal.csv ... 795
# reading /usr/share/mecab/dic/ipadic/Noun.org.csv ... 16668
# reading /usr/share/mecab/dic/ipadic/Noun.csv ... 60477
# reading /usr/share/mecab/dic/ipadic/Adnominal.csv ... 135
# reading /usr/share/mecab/dic/ipadic/Symbol.csv ... 208
# reading /usr/share/mecab/dic/ipadic/Adverb.csv ... 3032
# reading /usr/share/mecab/dic/ipadic/Noun.proper.csv ... 27327
# reading /usr/share/mecab/dic/ipadic/Postp-col.csv ... 91
# reading /usr/share/mecab/dic/ipadic/Adj.csv ... 27210
# reading /usr/share/mecab/dic/ipadic/Prefix.csv ... 221
# reading /usr/share/mecab/dic/ipadic/Noun.nai.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Noun.demonst.csv ... 120
# reading /usr/share/mecab/dic/ipadic/Noun.verbal.csv ... 12146
# reading /usr/share/mecab/dic/ipadic/Verb.csv ... 130750
# reading /usr/share/mecab/dic/ipadic/Noun.others.csv ... 151
# reading /usr/share/mecab/dic/ipadic/Postp.csv ... 146
# reading /usr/share/mecab/dic/ipadic/Interjection.csv ... 252
# emitting double-array: 100% |###########################################|
# reading /usr/share/mecab/dic/ipadic/matrix.def ... 1316x1316
# emitting matrix      : 100% |###########################################|
#
# done!
# Setting up mecab-jumandic (7.0-20130310-4) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
#
# Collecting mecab-python3==0.6
#   Downloading https://files.pythonhosted.org/packages/e3/7f/f98371035a0171abf95f9893eabf915f8a3199d005fed3cd69cc122fed40/mecab-python3-0.6.tar.gz (41kB)
#      |████████████████████████████████| 51kB 2.0MB/s
# Building wheels for collected packages: mecab-python3
#   Building wheel for mecab-python3 (setup.py) ... done
#   Created wheel for mecab-python3: filename=mecab_python3-0.6-cp36-cp36m-linux_x86_64.whl size=155475 sha256=ff541bf601503e6e56b4a599fe665742586c87e8f4aa18697850d0be5212938a
#   Stored in directory: /root/.cache/pip/wheels/4d/51/5b/987888cacaf8bb25982ef4569261f68debe85b7587c5563c79
# Successfully built mecab-python3
# Installing collected packages: mecab-python3
# Successfully installed mecab-python3-0.6

# %%
import numpy as np
import os
import time
import MeCab

import preprocess_utils
import model
import weight_utils

import tensorflow.keras as keras
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.3.0

# %% [markdown]
# # 日英翻訳データ ダウンロード

# %%
# !wget http://www.manythings.org/anki/jpn-eng.zip
# !unzip ./jpn-eng.zip

# %% [markdown]
# # データ読み込み

# %%
dataset = preprocess_utils.CreateData(
    corpus_path = './jpn.txt',
    do_shuffle=True,
    seed_value=123,
    split_percent=0.95 # 学習データの割合
)

train_source, train_target, test_source, test_target, train_licence, test_licence = dataset.split_data()

print('**** Amount of data ****')
print('train_source： ', len(train_source))
print('train_target： ', len(train_target))
print('test_source： ', len(test_source))
print('test_target： ', len(test_target))
print('\n')
print('**** Train data example ****')
print('Source Example： ', train_source[0])
print('Target Example： ', train_target[0])
print('Licence： ', train_licence[0])
print('\n')
print('**** Test data example ****')
print('Source Example： ', test_source[0])
print('Target Example： ', test_target[0])
print('Licence： ', test_licence[0])
# Out:
# **** Amount of data ****
# train_source：  52857
# train_target：  52857
# test_source：  2782
# test_target：  2782
#
#
# **** Train data example ****
# Source Example：  Look after Tom.
# Target Example：  トムの面倒を見てて。
# Licence：  CC-BY 2.0 (France) Attribution: tatoeba.org #2782602 (CK) & #2125677 (bunbuku)
#
#
#
# **** Test data example ****
# Source Example：  You should tell your mother as soon as possible.
# Target Example：  できるだけ早く、お母さんに知らせたほうがいい。
# Licence：  CC-BY 2.0 (France) Attribution: tatoeba.org #3554418 (CK) & #3553337 (arnab)

# %% [markdown]
# # 前処理

# %%
BATCH_SIZE = 64 # バッチサイズ
MAX_LENGTH = 60 # シーケンスの長さ
USE_TPU = True # TPUを使うか
BUFFER_SIZE = 50000

# %%
train_dataset = preprocess_utils.PreprocessData(
    mecab = MeCab.Tagger("-Ochasen"),
    source_data = train_source,
    target_data = train_target,
    max_length = MAX_LENGTH,
    batch_size = BATCH_SIZE,
    test_flag = False,
    train_dataset = None,
)

train_dataset.preprocess_data()

# %% [markdown]
# # バッチ作成

# %%
if USE_TPU:
  tpu_grpc_url = "grpc://" + os.environ["COLAB_TPU_ADDR"]
  tpu_cluster_resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu_grpc_url)
  tf.config.experimental_connect_to_cluster(tpu_cluster_resolver)
  tf.tpu.experimental.initialize_tpu_system(tpu_cluster_resolver)    
  strategy = tf.distribute.experimental.TPUStrategy(tpu_cluster_resolver)

trainset = tf.data.Dataset.from_tensor_slices((train_dataset.source_vector, train_dataset.target_vector))
trainset = trainset.map(lambda source, target: (tf.cast(source, tf.int64), tf.cast(target, tf.int64))).shuffle(buffer_size=BUFFER_SIZE).batch(BATCH_SIZE).prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

if USE_TPU:
  trainset = strategy.experimental_distribute_dataset(trainset)
# Out:
# INFO:tensorflow:Initializing the TPU system: grpc://10.90.231.226:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.90.231.226:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use  the non experimental symbol `tf.distribute.TPUStrategy` instead.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)

# %% [markdown]
# # モデル定義

# %%
num_layers=4 # レイヤー数
d_model=64 # 中間層の次元数
num_heads=4 # Multi Head Attentionのヘッド数
dff=2048 # Feed Forward Networkの次元数
dropout_rate = 0.1 # ドロップアウト率

source_vocab_size = max(train_dataset.source_token.values()) + 1 # source文の語彙数
target_vocab_size = max(train_dataset.target_token.values()) + 1 # target文の語彙数

# %%
# 重み初期化
def initialize_weight(checkpoint_path, optimizer, transformer, max_length, batch_size, use_tpu=False):

  if os.path.exists(checkpoint_path+'.pkl'):
    if use_tpu:
      number_of_tpu_cores = tpu_cluster_resolver.num_accelerators()['TPU']
      initialize_source, initialize_target = [[1]*max_length]*number_of_tpu_cores, [[1]*max_length]*number_of_tpu_cores
      initialize_set = tf.data.Dataset.from_tensor_slices((initialize_source, initialize_target))
      initialize_set = initialize_set.map(lambda source, target: (tf.cast(source, tf.int64), tf.cast(target, tf.int64))
          ).shuffle(buffer_size=BUFFER_SIZE).batch(batch_size).prefetch(
              buffer_size=tf.data.experimental.AUTOTUNE
          )
      initialize_set = strategy.experimental_distribute_dataset(initialize_set)

      for inp, tar in initialize_set:
        distributed_train_step(inp, tar)

    else:
      initialize_set = tf.ones([batch_size, max_length], tf.int64)
      train_step(initialize_set, initialize_set)
    
    try:
      weight_utils.load_weights_from_pickle(checkpoint_path, optimizer, transformer)
    except:
      print('Failed to load checkpoints.')

  else:
    print('No available checkpoints.')

# %% [markdown]
# # 学習実行

# %%
with strategy.scope():
  # Transformer
  transformer = model.Transformer(num_layers, d_model, num_heads, dff,
                            source_vocab_size, target_vocab_size, 
                            pe_input=source_vocab_size, 
                            pe_target=target_vocab_size,
                            rate=dropout_rate)

  # Learning Rate
  learning_rate = model.CustomSchedule(d_model)

  # Optimizer
  optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98, 
                                      epsilon=1e-9)

  # Loss
  loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')

  # Loss Function
  def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask
    return tf.reduce_mean(loss_)

  # Metrics
  train_loss = tf.keras.metrics.Mean(name='train_loss')
  train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='train_accuracy')

  # Checkpoint
  checkpoint_path = "/content/drive/My Drive/Transformer-master/checkpoints/tpu/model"


  def train_step(inp, tar):
    tar_inp = tar[:, :-1]
    tar_real = tar[:, 1:]
    
    enc_padding_mask, combined_mask, dec_padding_mask = model.create_masks(inp, tar_inp)
    
    with tf.GradientTape() as tape:
      predictions, _ = transformer(inp, tar_inp, 
                                  True, 
                                  enc_padding_mask, 
                                  combined_mask, 
                                  dec_padding_mask)
      loss = loss_function(tar_real, predictions)

    gradients = tape.gradient(loss, transformer.trainable_variables)    
    optimizer.apply_gradients(zip(gradients, transformer.trainable_variables))
    
    train_loss(loss)
    train_accuracy(tar_real, predictions)

  @tf.function
  def distributed_train_step(X, y):
    per_replica_losses = strategy.experimental_run_v2(train_step, args=(X, y))
    return strategy.reduce(tf.distribute.ReduceOp.MEAN, per_replica_losses, axis=None)

  # Initialize Weight
  initialize_weight(checkpoint_path, optimizer, transformer, MAX_LENGTH, BATCH_SIZE, use_tpu=USE_TPU)

  EPOCHS = 30
  batch = 0

  for epoch in range(EPOCHS):
    start = time.time()
    
    train_loss.reset_states()
    train_accuracy.reset_states()
    
    for inp, tar in trainset:
      distributed_train_step(inp, tar)
      
      if batch % 50 == 0:
        print ('Epoch {} Batch {} Loss {:.4f} Accuracy {:.4f}'.format(
            epoch + 1, batch, train_loss.result(), train_accuracy.result()))
        
      batch+=1
        
    if (epoch + 1) % 5 == 0:
      weight_utils.save_weights_as_pickle(checkpoint_path, optimizer, transformer)
      
    print ('Epoch {} Loss {:.4f} Accuracy {:.4f}'.format(epoch + 1, 
                                                  train_loss.result(), 
                                                  train_accuracy.result()))

    print ('Time taken for 1 epoch: {} secs\n'.format(time.time() - start))
# Out:
# No available checkpoints.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/multi_device_iterator_ops.py:601: get_next_as_optional (from tensorflow.python.data.ops.iterator_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Iterator.get_next_as_optional()` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/multi_device_iterator_ops.py:601: get_next_as_optional (from tensorflow.python.data.ops.iterator_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Iterator.get_next_as_optional()` instead.
# WARNING:tensorflow:From <ipython-input-12-e2d7056ebf55>:58: StrategyBase.experimental_run_v2 (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# renamed to `run`
# WARNING:tensorflow:From <ipython-input-12-e2d7056ebf55>:58: StrategyBase.experimental_run_v2 (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# renamed to `run`
# Epoch 1 Batch 0 Loss 1.9275 Accuracy 0.0000
# Epoch 1 Batch 50 Loss 1.7640 Accuracy 0.0043
# Epoch 1 Batch 100 Loss 1.7270 Accuracy 0.0098
# Epoch 1 Batch 150 Loss 1.7011 Accuracy 0.0114
# Epoch 1 Batch 200 Loss 1.6822 Accuracy 0.0125
# Epoch 1 Batch 250 Loss 1.6540 Accuracy 0.0156
# Epoch 1 Batch 300 Loss 1.6183 Accuracy 0.0181
# Epoch 1 Batch 350 Loss 1.5762 Accuracy 0.0200
# Epoch 1 Batch 400 Loss 1.5338 Accuracy 0.0214
# Epoch 1 Batch 450 Loss 1.4895 Accuracy 0.0225
# Epoch 1 Batch 500 Loss 1.4465 Accuracy 0.0235
# Epoch 1 Batch 550 Loss 1.4072 Accuracy 0.0246
# Epoch 1 Batch 600 Loss 1.3703 Accuracy 0.0257
# Epoch 1 Batch 650 Loss 1.3350 Accuracy 0.0271
# Epoch 1 Batch 700 Loss 1.3019 Accuracy 0.0287
# Epoch 1 Batch 750 Loss 1.2704 Accuracy 0.0303
# Epoch 1 Batch 800 Loss 1.2407 Accuracy 0.0319
# Epoch 1 Loss 1.2261 Accuracy 0.0327
# Time taken for 1 epoch: 147.74571800231934 secs
#
# Epoch 2 Batch 850 Loss 0.7646 Accuracy 0.0590
# Epoch 2 Batch 900 Loss 0.7458 Accuracy 0.0599
# Epoch 2 Batch 950 Loss 0.7396 Accuracy 0.0614
# Epoch 2 Batch 1000 Loss 0.7311 Accuracy 0.0621
# Epoch 2 Batch 1050 Loss 0.7276 Accuracy 0.0631
# Epoch 2 Batch 1100 Loss 0.7219 Accuracy 0.0642
# Epoch 2 Batch 1150 Loss 0.7163 Accuracy 0.0651
# Epoch 2 Batch 1200 Loss 0.7088 Accuracy 0.0658
# Epoch 2 Batch 1250 Loss 0.7044 Accuracy 0.0665
# Epoch 2 Batch 1300 Loss 0.6999 Accuracy 0.0671
# Epoch 2 Batch 1350 Loss 0.6956 Accuracy 0.0677
# Epoch 2 Batch 1400 Loss 0.6919 Accuracy 0.0683
# Epoch 2 Batch 1450 Loss 0.6884 Accuracy 0.0689
# Epoch 2 Batch 1500 Loss 0.6849 Accuracy 0.0694
# Epoch 2 Batch 1550 Loss 0.6813 Accuracy 0.0699
# Epoch 2 Batch 1600 Loss 0.6775 Accuracy 0.0703
# Epoch 2 Batch 1650 Loss 0.6739 Accuracy 0.0708
# Epoch 2 Loss 0.6739 Accuracy 0.0708
# Time taken for 1 epoch: 63.32995629310608 secs
#
# Epoch 3 Batch 1700 Loss 0.5983 Accuracy 0.0794
# Epoch 3 Batch 1750 Loss 0.5975 Accuracy 0.0796
# Epoch 3 Batch 1800 Loss 0.5957 Accuracy 0.0798
# Epoch 3 Batch 1850 Loss 0.5935 Accuracy 0.0799
# Epoch 3 Batch 1900 Loss 0.5946 Accuracy 0.0802
# Epoch 3 Batch 1950 Loss 0.5927 Accuracy 0.0805
# Epoch 3 Batch 2000 Loss 0.5910 Accuracy 0.0808
# Epoch 3 Batch 2050 Loss 0.5899 Accuracy 0.0809
# Epoch 3 Batch 2100 Loss 0.5887 Accuracy 0.0812
# Epoch 3 Batch 2150 Loss 0.5873 Accuracy 0.0814
# Epoch 3 Batch 2200 Loss 0.5863 Accuracy 0.0815
# Epoch 3 Batch 2250 Loss 0.5854 Accuracy 0.0818
# Epoch 3 Batch 2300 Loss 0.5843 Accuracy 0.0819
# Epoch 3 Batch 2350 Loss 0.5825 Accuracy 0.0821
# Epoch 3 Batch 2400 Loss 0.5809 Accuracy 0.0823
# Epoch 3 Batch 2450 Loss 0.5792 Accuracy 0.0826
# Epoch 3 Loss 0.5783 Accuracy 0.0828
# Time taken for 1 epoch: 63.96747040748596 secs
#
# Epoch 4 Batch 2500 Loss 0.5286 Accuracy 0.0875
# Epoch 4 Batch 2550 Loss 0.5214 Accuracy 0.0879
# Epoch 4 Batch 2600 Loss 0.5220 Accuracy 0.0883
# Epoch 4 Batch 2650 Loss 0.5196 Accuracy 0.0883
# Epoch 4 Batch 2700 Loss 0.5172 Accuracy 0.0884
# Epoch 4 Batch 2750 Loss 0.5164 Accuracy 0.0886
# Epoch 4 Batch 2800 Loss 0.5160 Accuracy 0.0890
# Epoch 4 Batch 2850 Loss 0.5170 Accuracy 0.0893
# Epoch 4 Batch 2900 Loss 0.5174 Accuracy 0.0895
# Epoch 4 Batch 2950 Loss 0.5161 Accuracy 0.0897
# Epoch 4 Batch 3000 Loss 0.5153 Accuracy 0.0899
# Epoch 4 Batch 3050 Loss 0.5140 Accuracy 0.0902
# Epoch 4 Batch 3100 Loss 0.5133 Accuracy 0.0904
# Epoch 4 Batch 3150 Loss 0.5121 Accuracy 0.0907
# Epoch 4 Batch 3200 Loss 0.5109 Accuracy 0.0909
# Epoch 4 Batch 3250 Loss 0.5102 Accuracy 0.0911
# Epoch 4 Batch 3300 Loss 0.5089 Accuracy 0.0913
# Epoch 4 Loss 0.5088 Accuracy 0.0913
# Time taken for 1 epoch: 63.70702338218689 secs
#
# Epoch 5 Batch 3350 Loss 0.4536 Accuracy 0.0979
# Epoch 5 Batch 3400 Loss 0.4610 Accuracy 0.0978
# Epoch 5 Batch 3450 Loss 0.4563 Accuracy 0.0978
# Epoch 5 Batch 3500 Loss 0.4548 Accuracy 0.0979
# Epoch 5 Batch 3550 Loss 0.4549 Accuracy 0.0982
# Epoch 5 Batch 3600 Loss 0.4543 Accuracy 0.0982
# Epoch 5 Batch 3650 Loss 0.4550 Accuracy 0.0982
# Epoch 5 Batch 3700 Loss 0.4549 Accuracy 0.0983
# Epoch 5 Batch 3750 Loss 0.4552 Accuracy 0.0985
# Epoch 5 Batch 3800 Loss 0.4553 Accuracy 0.0984
# Epoch 5 Batch 3850 Loss 0.4546 Accuracy 0.0984
# Epoch 5 Batch 3900 Loss 0.4543 Accuracy 0.0985
# Epoch 5 Batch 3950 Loss 0.4532 Accuracy 0.0986
# Epoch 5 Batch 4000 Loss 0.4520 Accuracy 0.0987
# Epoch 5 Batch 4050 Loss 0.4515 Accuracy 0.0988
# Epoch 5 Batch 4100 Loss 0.4507 Accuracy 0.0990
# Save checkpoints
# Epoch 5 Loss 0.4504 Accuracy 0.0991
# Time taken for 1 epoch: 65.36380100250244 secs
#
# Epoch 6 Batch 4150 Loss 0.4120 Accuracy 0.1055
# Epoch 6 Batch 4200 Loss 0.4049 Accuracy 0.1046
# Epoch 6 Batch 4250 Loss 0.4030 Accuracy 0.1046
# Epoch 6 Batch 4300 Loss 0.4018 Accuracy 0.1047
# Epoch 6 Batch 4350 Loss 0.4040 Accuracy 0.1050
# Epoch 6 Batch 4400 Loss 0.4048 Accuracy 0.1051
# Epoch 6 Batch 4450 Loss 0.4034 Accuracy 0.1052
# Epoch 6 Batch 4500 Loss 0.4036 Accuracy 0.1054
# Epoch 6 Batch 4550 Loss 0.4032 Accuracy 0.1053
# Epoch 6 Batch 4600 Loss 0.4031 Accuracy 0.1055
# Epoch 6 Batch 4650 Loss 0.4032 Accuracy 0.1056
# Epoch 6 Batch 4700 Loss 0.4035 Accuracy 0.1057
# Epoch 6 Batch 4750 Loss 0.4031 Accuracy 0.1057
# Epoch 6 Batch 4800 Loss 0.4030 Accuracy 0.1058
# Epoch 6 Batch 4850 Loss 0.4029 Accuracy 0.1058
# Epoch 6 Batch 4900 Loss 0.4021 Accuracy 0.1060
# Epoch 6 Batch 4950 Loss 0.4014 Accuracy 0.1061
# Epoch 6 Loss 0.4014 Accuracy 0.1061
# Time taken for 1 epoch: 64.58942723274231 secs
#
# Epoch 7 Batch 5000 Loss 0.3465 Accuracy 0.1113
# Epoch 7 Batch 5050 Loss 0.3518 Accuracy 0.1113
# Epoch 7 Batch 5100 Loss 0.3542 Accuracy 0.1113
# Epoch 7 Batch 5150 Loss 0.3552 Accuracy 0.1113
# Epoch 7 Batch 5200 Loss 0.3566 Accuracy 0.1112
# Epoch 7 Batch 5250 Loss 0.3565 Accuracy 0.1115
# Epoch 7 Batch 5300 Loss 0.3575 Accuracy 0.1115
# Epoch 7 Batch 5350 Loss 0.3592 Accuracy 0.1115
# Epoch 7 Batch 5400 Loss 0.3605 Accuracy 0.1115
# Epoch 7 Batch 5450 Loss 0.3609 Accuracy 0.1114
# Epoch 7 Batch 5500 Loss 0.3625 Accuracy 0.1114
# Epoch 7 Batch 5550 Loss 0.3621 Accuracy 0.1114
# Epoch 7 Batch 5600 Loss 0.3631 Accuracy 0.1114
# Epoch 7 Batch 5650 Loss 0.3634 Accuracy 0.1114
# Epoch 7 Batch 5700 Loss 0.3640 Accuracy 0.1114
# Epoch 7 Batch 5750 Loss 0.3642 Accuracy 0.1114
# Epoch 7 Loss 0.3646 Accuracy 0.1115
# Time taken for 1 epoch: 64.18417429924011 secs
#
# Epoch 8 Batch 5800 Loss 0.3351 Accuracy 0.1161
# Epoch 8 Batch 5850 Loss 0.3311 Accuracy 0.1172
# Epoch 8 Batch 5900 Loss 0.3321 Accuracy 0.1166
# Epoch 8 Batch 5950 Loss 0.3321 Accuracy 0.1164
# Epoch 8 Batch 6000 Loss 0.3310 Accuracy 0.1163
# Epoch 8 Batch 6050 Loss 0.3320 Accuracy 0.1162
# Epoch 8 Batch 6100 Loss 0.3337 Accuracy 0.1160
# Epoch 8 Batch 6150 Loss 0.3344 Accuracy 0.1160
# Epoch 8 Batch 6200 Loss 0.3361 Accuracy 0.1162
# Epoch 8 Batch 6250 Loss 0.3366 Accuracy 0.1160
# Epoch 8 Batch 6300 Loss 0.3371 Accuracy 0.1160
# Epoch 8 Batch 6350 Loss 0.3374 Accuracy 0.1159
# Epoch 8 Batch 6400 Loss 0.3383 Accuracy 0.1158
# Epoch 8 Batch 6450 Loss 0.3385 Accuracy 0.1158
# Epoch 8 Batch 6500 Loss 0.3388 Accuracy 0.1157
# Epoch 8 Batch 6550 Loss 0.3391 Accuracy 0.1156
# Epoch 8 Batch 6600 Loss 0.3398 Accuracy 0.1156
# Epoch 8 Loss 0.3398 Accuracy 0.1156
# Time taken for 1 epoch: 64.83749556541443 secs
#
# Epoch 9 Batch 6650 Loss 0.3052 Accuracy 0.1198
# Epoch 9 Batch 6700 Loss 0.3092 Accuracy 0.1201
# Epoch 9 Batch 6750 Loss 0.3087 Accuracy 0.1198
# Epoch 9 Batch 6800 Loss 0.3088 Accuracy 0.1195
# Epoch 9 Batch 6850 Loss 0.3099 Accuracy 0.1195
# Epoch 9 Batch 6900 Loss 0.3112 Accuracy 0.1194
# Epoch 9 Batch 6950 Loss 0.3133 Accuracy 0.1191
# Epoch 9 Batch 7000 Loss 0.3147 Accuracy 0.1192
# Epoch 9 Batch 7050 Loss 0.3151 Accuracy 0.1192
# Epoch 9 Batch 7100 Loss 0.3164 Accuracy 0.1190
# Epoch 9 Batch 7150 Loss 0.3166 Accuracy 0.1190
# Epoch 9 Batch 7200 Loss 0.3171 Accuracy 0.1189
# Epoch 9 Batch 7250 Loss 0.3184 Accuracy 0.1188
# Epoch 9 Batch 7300 Loss 0.3197 Accuracy 0.1187
# Epoch 9 Batch 7350 Loss 0.3203 Accuracy 0.1187
# Epoch 9 Batch 7400 Loss 0.3205 Accuracy 0.1187
# Epoch 9 Loss 0.3211 Accuracy 0.1187
# Time taken for 1 epoch: 64.76928162574768 secs
#
# Epoch 10 Batch 7450 Loss 0.3072 Accuracy 0.1223
# Epoch 10 Batch 7500 Loss 0.2972 Accuracy 0.1236
# Epoch 10 Batch 7550 Loss 0.2931 Accuracy 0.1228
# Epoch 10 Batch 7600 Loss 0.2926 Accuracy 0.1222
# Epoch 10 Batch 7650 Loss 0.2934 Accuracy 0.1220
# Epoch 10 Batch 7700 Loss 0.2966 Accuracy 0.1220
# Epoch 10 Batch 7750 Loss 0.2972 Accuracy 0.1220
# Epoch 10 Batch 7800 Loss 0.2987 Accuracy 0.1217
# Epoch 10 Batch 7850 Loss 0.2996 Accuracy 0.1218
# Epoch 10 Batch 7900 Loss 0.3002 Accuracy 0.1218
# Epoch 10 Batch 7950 Loss 0.3003 Accuracy 0.1217
# Epoch 10 Batch 8000 Loss 0.3016 Accuracy 0.1217
# Epoch 10 Batch 8050 Loss 0.3025 Accuracy 0.1217
# Epoch 10 Batch 8100 Loss 0.3031 Accuracy 0.1216
# Epoch 10 Batch 8150 Loss 0.3037 Accuracy 0.1214
# Epoch 10 Batch 8200 Loss 0.3043 Accuracy 0.1214
# Epoch 10 Batch 8250 Loss 0.3045 Accuracy 0.1214
# Save checkpoints
# Epoch 10 Loss 0.3045 Accuracy 0.1214
# Time taken for 1 epoch: 65.16681408882141 secs
#
# Epoch 11 Batch 8300 Loss 0.2665 Accuracy 0.1258
# Epoch 11 Batch 8350 Loss 0.2748 Accuracy 0.1255
# Epoch 11 Batch 8400 Loss 0.2782 Accuracy 0.1254
# Epoch 11 Batch 8450 Loss 0.2785 Accuracy 0.1248
# Epoch 11 Batch 8500 Loss 0.2804 Accuracy 0.1245
# Epoch 11 Batch 8550 Loss 0.2833 Accuracy 0.1243
# Epoch 11 Batch 8600 Loss 0.2835 Accuracy 0.1241
# Epoch 11 Batch 8650 Loss 0.2853 Accuracy 0.1240
# Epoch 11 Batch 8700 Loss 0.2868 Accuracy 0.1239
# Epoch 11 Batch 8750 Loss 0.2876 Accuracy 0.1239
# Epoch 11 Batch 8800 Loss 0.2889 Accuracy 0.1238
# Epoch 11 Batch 8850 Loss 0.2892 Accuracy 0.1237
# Epoch 11 Batch 8900 Loss 0.2903 Accuracy 0.1237
# Epoch 11 Batch 8950 Loss 0.2913 Accuracy 0.1237
# Epoch 11 Batch 9000 Loss 0.2921 Accuracy 0.1236
# Epoch 11 Batch 9050 Loss 0.2924 Accuracy 0.1235
# Epoch 11 Loss 0.2922 Accuracy 0.1234
# Time taken for 1 epoch: 64.64775943756104 secs
#
# Epoch 12 Batch 9100 Loss 0.2672 Accuracy 0.1285
# Epoch 12 Batch 9150 Loss 0.2628 Accuracy 0.1266
# Epoch 12 Batch 9200 Loss 0.2649 Accuracy 0.1265
# Epoch 12 Batch 9250 Loss 0.2663 Accuracy 0.1262
# Epoch 12 Batch 9300 Loss 0.2670 Accuracy 0.1261
# Epoch 12 Batch 9350 Loss 0.2680 Accuracy 0.1260
# Epoch 12 Batch 9400 Loss 0.2693 Accuracy 0.1258
# Epoch 12 Batch 9450 Loss 0.2707 Accuracy 0.1258
# Epoch 12 Batch 9500 Loss 0.2720 Accuracy 0.1257
# Epoch 12 Batch 9550 Loss 0.2734 Accuracy 0.1255
# Epoch 12 Batch 9600 Loss 0.2749 Accuracy 0.1255
# Epoch 12 Batch 9650 Loss 0.2760 Accuracy 0.1253
# Epoch 12 Batch 9700 Loss 0.2775 Accuracy 0.1253
# Epoch 12 Batch 9750 Loss 0.2789 Accuracy 0.1253
# Epoch 12 Batch 9800 Loss 0.2795 Accuracy 0.1254
# Epoch 12 Batch 9850 Loss 0.2806 Accuracy 0.1253
# Epoch 12 Batch 9900 Loss 0.2815 Accuracy 0.1252
# Epoch 12 Loss 0.2815 Accuracy 0.1252
# Time taken for 1 epoch: 63.21405649185181 secs
#
# Epoch 13 Batch 9950 Loss 0.2514 Accuracy 0.1265
# Epoch 13 Batch 10000 Loss 0.2544 Accuracy 0.1286
# Epoch 13 Batch 10050 Loss 0.2560 Accuracy 0.1287
# Epoch 13 Batch 10100 Loss 0.2577 Accuracy 0.1282
# Epoch 13 Batch 10150 Loss 0.2593 Accuracy 0.1281
# Epoch 13 Batch 10200 Loss 0.2626 Accuracy 0.1279
# Epoch 13 Batch 10250 Loss 0.2641 Accuracy 0.1277
# Epoch 13 Batch 10300 Loss 0.2655 Accuracy 0.1276
# Epoch 13 Batch 10350 Loss 0.2658 Accuracy 0.1274
# Epoch 13 Batch 10400 Loss 0.2670 Accuracy 0.1274
# Epoch 13 Batch 10450 Loss 0.2675 Accuracy 0.1273
# Epoch 13 Batch 10500 Loss 0.2688 Accuracy 0.1273
# Epoch 13 Batch 10550 Loss 0.2694 Accuracy 0.1271
# Epoch 13 Batch 10600 Loss 0.2701 Accuracy 0.1271
# Epoch 13 Batch 10650 Loss 0.2703 Accuracy 0.1271
# Epoch 13 Batch 10700 Loss 0.2715 Accuracy 0.1270
# Epoch 13 Loss 0.2718 Accuracy 0.1269
# Time taken for 1 epoch: 63.69023370742798 secs
#
# Epoch 14 Batch 10750 Loss 0.2573 Accuracy 0.1302
# Epoch 14 Batch 10800 Loss 0.2524 Accuracy 0.1315
# Epoch 14 Batch 10850 Loss 0.2521 Accuracy 0.1308
# Epoch 14 Batch 10900 Loss 0.2536 Accuracy 0.1302
# Epoch 14 Batch 10950 Loss 0.2546 Accuracy 0.1299
# Epoch 14 Batch 11000 Loss 0.2552 Accuracy 0.1296
# Epoch 14 Batch 11050 Loss 0.2558 Accuracy 0.1292
# Epoch 14 Batch 11100 Loss 0.2572 Accuracy 0.1291
# Epoch 14 Batch 11150 Loss 0.2582 Accuracy 0.1289
# Epoch 14 Batch 11200 Loss 0.2587 Accuracy 0.1288
# Epoch 14 Batch 11250 Loss 0.2593 Accuracy 0.1287
# Epoch 14 Batch 11300 Loss 0.2593 Accuracy 0.1286
# Epoch 14 Batch 11350 Loss 0.2602 Accuracy 0.1285
# Epoch 14 Batch 11400 Loss 0.2609 Accuracy 0.1284
# Epoch 14 Batch 11450 Loss 0.2614 Accuracy 0.1284
# Epoch 14 Batch 11500 Loss 0.2625 Accuracy 0.1283
# Epoch 14 Batch 11550 Loss 0.2633 Accuracy 0.1283
# Epoch 14 Loss 0.2635 Accuracy 0.1283
# Time taken for 1 epoch: 64.32965302467346 secs
#
# Epoch 15 Batch 11600 Loss 0.2390 Accuracy 0.1318
# Epoch 15 Batch 11650 Loss 0.2412 Accuracy 0.1312
# Epoch 15 Batch 11700 Loss 0.2420 Accuracy 0.1309
# Epoch 15 Batch 11750 Loss 0.2426 Accuracy 0.1304
# Epoch 15 Batch 11800 Loss 0.2443 Accuracy 0.1302
# Epoch 15 Batch 11850 Loss 0.2459 Accuracy 0.1304
# Epoch 15 Batch 11900 Loss 0.2478 Accuracy 0.1301
# Epoch 15 Batch 11950 Loss 0.2489 Accuracy 0.1300
# Epoch 15 Batch 12000 Loss 0.2496 Accuracy 0.1299
# Epoch 15 Batch 12050 Loss 0.2508 Accuracy 0.1298
# Epoch 15 Batch 12100 Loss 0.2523 Accuracy 0.1297
# Epoch 15 Batch 12150 Loss 0.2529 Accuracy 0.1296
# Epoch 15 Batch 12200 Loss 0.2539 Accuracy 0.1296
# Epoch 15 Batch 12250 Loss 0.2546 Accuracy 0.1296
# Epoch 15 Batch 12300 Loss 0.2554 Accuracy 0.1295
# Epoch 15 Batch 12350 Loss 0.2560 Accuracy 0.1294
# Save checkpoints
# Epoch 15 Loss 0.2569 Accuracy 0.1294
# Time taken for 1 epoch: 65.68406438827515 secs
#
# Epoch 16 Batch 12400 Loss 0.2255 Accuracy 0.1301
# Epoch 16 Batch 12450 Loss 0.2315 Accuracy 0.1318
# Epoch 16 Batch 12500 Loss 0.2334 Accuracy 0.1317
# Epoch 16 Batch 12550 Loss 0.2358 Accuracy 0.1314
# Epoch 16 Batch 12600 Loss 0.2366 Accuracy 0.1315
# Epoch 16 Batch 12650 Loss 0.2385 Accuracy 0.1318
# Epoch 16 Batch 12700 Loss 0.2399 Accuracy 0.1315
# Epoch 16 Batch 12750 Loss 0.2395 Accuracy 0.1313
# Epoch 16 Batch 12800 Loss 0.2406 Accuracy 0.1311
# Epoch 16 Batch 12850 Loss 0.2429 Accuracy 0.1312
# Epoch 16 Batch 12900 Loss 0.2441 Accuracy 0.1312
# Epoch 16 Batch 12950 Loss 0.2452 Accuracy 0.1311
# Epoch 16 Batch 13000 Loss 0.2459 Accuracy 0.1311
# Epoch 16 Batch 13050 Loss 0.2472 Accuracy 0.1310
# Epoch 16 Batch 13100 Loss 0.2484 Accuracy 0.1309
# Epoch 16 Batch 13150 Loss 0.2494 Accuracy 0.1309
# Epoch 16 Batch 13200 Loss 0.2499 Accuracy 0.1307
# Epoch 16 Loss 0.2503 Accuracy 0.1307
# Time taken for 1 epoch: 64.65343952178955 secs
#
# Epoch 17 Batch 13250 Loss 0.2252 Accuracy 0.1344
# Epoch 17 Batch 13300 Loss 0.2249 Accuracy 0.1333
# Epoch 17 Batch 13350 Loss 0.2262 Accuracy 0.1333
# Epoch 17 Batch 13400 Loss 0.2292 Accuracy 0.1331
# Epoch 17 Batch 13450 Loss 0.2312 Accuracy 0.1331
# Epoch 17 Batch 13500 Loss 0.2324 Accuracy 0.1331
# Epoch 17 Batch 13550 Loss 0.2345 Accuracy 0.1329
# Epoch 17 Batch 13600 Loss 0.2359 Accuracy 0.1326
# Epoch 17 Batch 13650 Loss 0.2374 Accuracy 0.1326
# Epoch 17 Batch 13700 Loss 0.2386 Accuracy 0.1324
# Epoch 17 Batch 13750 Loss 0.2398 Accuracy 0.1323
# Epoch 17 Batch 13800 Loss 0.2410 Accuracy 0.1322
# Epoch 17 Batch 13850 Loss 0.2418 Accuracy 0.1320
# Epoch 17 Batch 13900 Loss 0.2425 Accuracy 0.1319
# Epoch 17 Batch 13950 Loss 0.2435 Accuracy 0.1319
# Epoch 17 Batch 14000 Loss 0.2445 Accuracy 0.1318
# Epoch 17 Loss 0.2449 Accuracy 0.1317
# Time taken for 1 epoch: 64.12510371208191 secs
#
# Epoch 18 Batch 14050 Loss 0.2231 Accuracy 0.1377
# Epoch 18 Batch 14100 Loss 0.2195 Accuracy 0.1351
# Epoch 18 Batch 14150 Loss 0.2225 Accuracy 0.1345
# Epoch 18 Batch 14200 Loss 0.2239 Accuracy 0.1342
# Epoch 18 Batch 14250 Loss 0.2243 Accuracy 0.1340
# Epoch 18 Batch 14300 Loss 0.2259 Accuracy 0.1341
# Epoch 18 Batch 14350 Loss 0.2287 Accuracy 0.1341
# Epoch 18 Batch 14400 Loss 0.2301 Accuracy 0.1340
# Epoch 18 Batch 14450 Loss 0.2317 Accuracy 0.1338
# Epoch 18 Batch 14500 Loss 0.2331 Accuracy 0.1337
# Epoch 18 Batch 14550 Loss 0.2344 Accuracy 0.1335
# Epoch 18 Batch 14600 Loss 0.2356 Accuracy 0.1335
# Epoch 18 Batch 14650 Loss 0.2366 Accuracy 0.1334
# Epoch 18 Batch 14700 Loss 0.2376 Accuracy 0.1332
# Epoch 18 Batch 14750 Loss 0.2385 Accuracy 0.1330
# Epoch 18 Batch 14800 Loss 0.2393 Accuracy 0.1329
# Epoch 18 Batch 14850 Loss 0.2398 Accuracy 0.1327
# Epoch 18 Loss 0.2400 Accuracy 0.1327
# Time taken for 1 epoch: 63.96518278121948 secs
#
# Epoch 19 Batch 14900 Loss 0.2175 Accuracy 0.1347
# Epoch 19 Batch 14950 Loss 0.2155 Accuracy 0.1352
# Epoch 19 Batch 15000 Loss 0.2178 Accuracy 0.1347
# Epoch 19 Batch 15050 Loss 0.2199 Accuracy 0.1346
# Epoch 19 Batch 15100 Loss 0.2219 Accuracy 0.1347
# Epoch 19 Batch 15150 Loss 0.2235 Accuracy 0.1348
# Epoch 19 Batch 15200 Loss 0.2248 Accuracy 0.1345
# Epoch 19 Batch 15250 Loss 0.2259 Accuracy 0.1341
# Epoch 19 Batch 15300 Loss 0.2275 Accuracy 0.1341
# Epoch 19 Batch 15350 Loss 0.2282 Accuracy 0.1340
# Epoch 19 Batch 15400 Loss 0.2300 Accuracy 0.1338
# Epoch 19 Batch 15450 Loss 0.2313 Accuracy 0.1337
# Epoch 19 Batch 15500 Loss 0.2318 Accuracy 0.1337
# Epoch 19 Batch 15550 Loss 0.2325 Accuracy 0.1335
# Epoch 19 Batch 15600 Loss 0.2342 Accuracy 0.1335
# Epoch 19 Batch 15650 Loss 0.2350 Accuracy 0.1334
# Epoch 19 Loss 0.2357 Accuracy 0.1334
# Time taken for 1 epoch: 65.009920835495 secs
#
# Epoch 20 Batch 15700 Loss 0.2195 Accuracy 0.1354
# Epoch 20 Batch 15750 Loss 0.2141 Accuracy 0.1367
# Epoch 20 Batch 15800 Loss 0.2143 Accuracy 0.1364
# Epoch 20 Batch 15850 Loss 0.2144 Accuracy 0.1360
# Epoch 20 Batch 15900 Loss 0.2150 Accuracy 0.1356
# Epoch 20 Batch 15950 Loss 0.2171 Accuracy 0.1355
# Epoch 20 Batch 16000 Loss 0.2190 Accuracy 0.1354
# Epoch 20 Batch 16050 Loss 0.2202 Accuracy 0.1352
# Epoch 20 Batch 16100 Loss 0.2219 Accuracy 0.1352
# Epoch 20 Batch 16150 Loss 0.2237 Accuracy 0.1352
# Epoch 20 Batch 16200 Loss 0.2249 Accuracy 0.1350
# Epoch 20 Batch 16250 Loss 0.2255 Accuracy 0.1347
# Epoch 20 Batch 16300 Loss 0.2270 Accuracy 0.1346
# Epoch 20 Batch 16350 Loss 0.2285 Accuracy 0.1344
# Epoch 20 Batch 16400 Loss 0.2295 Accuracy 0.1344
# Epoch 20 Batch 16450 Loss 0.2301 Accuracy 0.1343
# Epoch 20 Batch 16500 Loss 0.2310 Accuracy 0.1342
# Save checkpoints
# Epoch 20 Loss 0.2315 Accuracy 0.1342
# Time taken for 1 epoch: 66.06526136398315 secs
#
# Epoch 21 Batch 16550 Loss 0.2068 Accuracy 0.1354
# Epoch 21 Batch 16600 Loss 0.2085 Accuracy 0.1364
# Epoch 21 Batch 16650 Loss 0.2121 Accuracy 0.1369
# Epoch 21 Batch 16700 Loss 0.2123 Accuracy 0.1369
# Epoch 21 Batch 16750 Loss 0.2136 Accuracy 0.1367
# Epoch 21 Batch 16800 Loss 0.2150 Accuracy 0.1365
# Epoch 21 Batch 16850 Loss 0.2172 Accuracy 0.1364
# Epoch 21 Batch 16900 Loss 0.2176 Accuracy 0.1361
# Epoch 21 Batch 16950 Loss 0.2189 Accuracy 0.1360
# Epoch 21 Batch 17000 Loss 0.2205 Accuracy 0.1360
# Epoch 21 Batch 17050 Loss 0.2210 Accuracy 0.1356
# Epoch 21 Batch 17100 Loss 0.2223 Accuracy 0.1355
# Epoch 21 Batch 17150 Loss 0.2236 Accuracy 0.1354
# Epoch 21 Batch 17200 Loss 0.2238 Accuracy 0.1353
# Epoch 21 Batch 17250 Loss 0.2254 Accuracy 0.1351
# Epoch 21 Batch 17300 Loss 0.2266 Accuracy 0.1350
# Epoch 21 Loss 0.2272 Accuracy 0.1350
# Time taken for 1 epoch: 64.55305933952332 secs
#
# Epoch 22 Batch 17350 Loss 0.2028 Accuracy 0.1418
# Epoch 22 Batch 17400 Loss 0.2023 Accuracy 0.1386
# Epoch 22 Batch 17450 Loss 0.2054 Accuracy 0.1383
# Epoch 22 Batch 17500 Loss 0.2070 Accuracy 0.1381
# Epoch 22 Batch 17550 Loss 0.2094 Accuracy 0.1377
# Epoch 22 Batch 17600 Loss 0.2107 Accuracy 0.1375
# Epoch 22 Batch 17650 Loss 0.2127 Accuracy 0.1375
# Epoch 22 Batch 17700 Loss 0.2144 Accuracy 0.1371
# Epoch 22 Batch 17750 Loss 0.2150 Accuracy 0.1370
# Epoch 22 Batch 17800 Loss 0.2160 Accuracy 0.1368
# Epoch 22 Batch 17850 Loss 0.2173 Accuracy 0.1366
# Epoch 22 Batch 17900 Loss 0.2175 Accuracy 0.1363
# Epoch 22 Batch 17950 Loss 0.2187 Accuracy 0.1361
# Epoch 22 Batch 18000 Loss 0.2197 Accuracy 0.1360
# Epoch 22 Batch 18050 Loss 0.2212 Accuracy 0.1359
# Epoch 22 Batch 18100 Loss 0.2224 Accuracy 0.1358
# Epoch 22 Batch 18150 Loss 0.2235 Accuracy 0.1357
# Epoch 22 Loss 0.2238 Accuracy 0.1356
# Time taken for 1 epoch: 64.21828126907349 secs
#
# Epoch 23 Batch 18200 Loss 0.1989 Accuracy 0.1396
# Epoch 23 Batch 18250 Loss 0.1990 Accuracy 0.1393
# Epoch 23 Batch 18300 Loss 0.2012 Accuracy 0.1388
# Epoch 23 Batch 18350 Loss 0.2033 Accuracy 0.1383
# Epoch 23 Batch 18400 Loss 0.2039 Accuracy 0.1381
# Epoch 23 Batch 18450 Loss 0.2068 Accuracy 0.1381
# Epoch 23 Batch 18500 Loss 0.2086 Accuracy 0.1377
# Epoch 23 Batch 18550 Loss 0.2107 Accuracy 0.1376
# Epoch 23 Batch 18600 Loss 0.2112 Accuracy 0.1375
# Epoch 23 Batch 18650 Loss 0.2123 Accuracy 0.1374
# Epoch 23 Batch 18700 Loss 0.2136 Accuracy 0.1372
# Epoch 23 Batch 18750 Loss 0.2145 Accuracy 0.1371
# Epoch 23 Batch 18800 Loss 0.2156 Accuracy 0.1370
# Epoch 23 Batch 18850 Loss 0.2170 Accuracy 0.1368
# Epoch 23 Batch 18900 Loss 0.2184 Accuracy 0.1367
# Epoch 23 Batch 18950 Loss 0.2194 Accuracy 0.1366
# Epoch 23 Loss 0.2206 Accuracy 0.1364
# Time taken for 1 epoch: 63.74313306808472 secs
#
# Epoch 24 Batch 19000 Loss 0.1764 Accuracy 0.1383
# Epoch 24 Batch 19050 Loss 0.1926 Accuracy 0.1379
# Epoch 24 Batch 19100 Loss 0.1979 Accuracy 0.1384
# Epoch 24 Batch 19150 Loss 0.1993 Accuracy 0.1381
# Epoch 24 Batch 19200 Loss 0.2011 Accuracy 0.1378
# Epoch 24 Batch 19250 Loss 0.2032 Accuracy 0.1379
# Epoch 24 Batch 19300 Loss 0.2047 Accuracy 0.1379
# Epoch 24 Batch 19350 Loss 0.2061 Accuracy 0.1378
# Epoch 24 Batch 19400 Loss 0.2078 Accuracy 0.1377
# Epoch 24 Batch 19450 Loss 0.2093 Accuracy 0.1378
# Epoch 24 Batch 19500 Loss 0.2101 Accuracy 0.1377
# Epoch 24 Batch 19550 Loss 0.2115 Accuracy 0.1375
# Epoch 24 Batch 19600 Loss 0.2125 Accuracy 0.1374
# Epoch 24 Batch 19650 Loss 0.2139 Accuracy 0.1373
# Epoch 24 Batch 19700 Loss 0.2150 Accuracy 0.1372
# Epoch 24 Batch 19750 Loss 0.2162 Accuracy 0.1372
# Epoch 24 Batch 19800 Loss 0.2172 Accuracy 0.1371
# Epoch 24 Loss 0.2176 Accuracy 0.1370
# Time taken for 1 epoch: 65.59664177894592 secs
#
# Epoch 25 Batch 19850 Loss 0.1979 Accuracy 0.1416
# Epoch 25 Batch 19900 Loss 0.1969 Accuracy 0.1405
# Epoch 25 Batch 19950 Loss 0.1968 Accuracy 0.1398
# Epoch 25 Batch 20000 Loss 0.2007 Accuracy 0.1395
# Epoch 25 Batch 20050 Loss 0.2012 Accuracy 0.1393
# Epoch 25 Batch 20100 Loss 0.2024 Accuracy 0.1390
# Epoch 25 Batch 20150 Loss 0.2036 Accuracy 0.1390
# Epoch 25 Batch 20200 Loss 0.2050 Accuracy 0.1386
# Epoch 25 Batch 20250 Loss 0.2066 Accuracy 0.1385
# Epoch 25 Batch 20300 Loss 0.2083 Accuracy 0.1382
# Epoch 25 Batch 20350 Loss 0.2093 Accuracy 0.1381
# Epoch 25 Batch 20400 Loss 0.2098 Accuracy 0.1382
# Epoch 25 Batch 20450 Loss 0.2112 Accuracy 0.1380
# Epoch 25 Batch 20500 Loss 0.2116 Accuracy 0.1378
# Epoch 25 Batch 20550 Loss 0.2129 Accuracy 0.1377
# Epoch 25 Batch 20600 Loss 0.2140 Accuracy 0.1375
# Save checkpoints
# Epoch 25 Loss 0.2146 Accuracy 0.1374
# Time taken for 1 epoch: 68.64437937736511 secs
#
# Epoch 26 Batch 20650 Loss 0.1835 Accuracy 0.1406
# Epoch 26 Batch 20700 Loss 0.1928 Accuracy 0.1398
# Epoch 26 Batch 20750 Loss 0.1920 Accuracy 0.1400
# Epoch 26 Batch 20800 Loss 0.1935 Accuracy 0.1398
# Epoch 26 Batch 20850 Loss 0.1946 Accuracy 0.1395
# Epoch 26 Batch 20900 Loss 0.1973 Accuracy 0.1394
# Epoch 26 Batch 20950 Loss 0.1985 Accuracy 0.1392
# Epoch 26 Batch 21000 Loss 0.2002 Accuracy 0.1392
# Epoch 26 Batch 21050 Loss 0.2021 Accuracy 0.1389
# Epoch 26 Batch 21100 Loss 0.2032 Accuracy 0.1389
# Epoch 26 Batch 21150 Loss 0.2043 Accuracy 0.1388
# Epoch 26 Batch 21200 Loss 0.2054 Accuracy 0.1386
# Epoch 26 Batch 21250 Loss 0.2068 Accuracy 0.1385
# Epoch 26 Batch 21300 Loss 0.2080 Accuracy 0.1384
# Epoch 26 Batch 21350 Loss 0.2089 Accuracy 0.1383
# Epoch 26 Batch 21400 Loss 0.2102 Accuracy 0.1383
# Epoch 26 Batch 21450 Loss 0.2110 Accuracy 0.1381
# Epoch 26 Loss 0.2117 Accuracy 0.1381
# Time taken for 1 epoch: 65.05703353881836 secs
#
# Epoch 27 Batch 21500 Loss 0.1835 Accuracy 0.1394
# Epoch 27 Batch 21550 Loss 0.1860 Accuracy 0.1396
# Epoch 27 Batch 21600 Loss 0.1892 Accuracy 0.1403
# Epoch 27 Batch 21650 Loss 0.1932 Accuracy 0.1403
# Epoch 27 Batch 21700 Loss 0.1943 Accuracy 0.1400
# Epoch 27 Batch 21750 Loss 0.1963 Accuracy 0.1401
# Epoch 27 Batch 21800 Loss 0.1980 Accuracy 0.1399
# Epoch 27 Batch 21850 Loss 0.2003 Accuracy 0.1396
# Epoch 27 Batch 21900 Loss 0.2009 Accuracy 0.1393
# Epoch 27 Batch 21950 Loss 0.2024 Accuracy 0.1392
# Epoch 27 Batch 22000 Loss 0.2029 Accuracy 0.1390
# Epoch 27 Batch 22050 Loss 0.2039 Accuracy 0.1391
# Epoch 27 Batch 22100 Loss 0.2047 Accuracy 0.1390
# Epoch 27 Batch 22150 Loss 0.2061 Accuracy 0.1389
# Epoch 27 Batch 22200 Loss 0.2069 Accuracy 0.1388
# Epoch 27 Batch 22250 Loss 0.2081 Accuracy 0.1387
# Epoch 27 Batch 22300 Loss 0.2090 Accuracy 0.1386
# Epoch 27 Loss 0.2091 Accuracy 0.1386
# Time taken for 1 epoch: 65.40553021430969 secs
#
# Epoch 28 Batch 22350 Loss 0.1841 Accuracy 0.1419
# Epoch 28 Batch 22400 Loss 0.1846 Accuracy 0.1411
# Epoch 28 Batch 22450 Loss 0.1875 Accuracy 0.1408
# Epoch 28 Batch 22500 Loss 0.1904 Accuracy 0.1410
# Epoch 28 Batch 22550 Loss 0.1913 Accuracy 0.1408
# Epoch 28 Batch 22600 Loss 0.1936 Accuracy 0.1405
# Epoch 28 Batch 22650 Loss 0.1951 Accuracy 0.1404
# Epoch 28 Batch 22700 Loss 0.1963 Accuracy 0.1402
# Epoch 28 Batch 22750 Loss 0.1978 Accuracy 0.1402
# Epoch 28 Batch 22800 Loss 0.1992 Accuracy 0.1401
# Epoch 28 Batch 22850 Loss 0.2005 Accuracy 0.1398
# Epoch 28 Batch 22900 Loss 0.2015 Accuracy 0.1396
# Epoch 28 Batch 22950 Loss 0.2026 Accuracy 0.1395
# Epoch 28 Batch 23000 Loss 0.2041 Accuracy 0.1394
# Epoch 28 Batch 23050 Loss 0.2053 Accuracy 0.1392
# Epoch 28 Batch 23100 Loss 0.2061 Accuracy 0.1391
# Epoch 28 Loss 0.2068 Accuracy 0.1390
# Time taken for 1 epoch: 64.98134660720825 secs
#
# Epoch 29 Batch 23150 Loss 0.1777 Accuracy 0.1425
# Epoch 29 Batch 23200 Loss 0.1827 Accuracy 0.1422
# Epoch 29 Batch 23250 Loss 0.1859 Accuracy 0.1420
# Epoch 29 Batch 23300 Loss 0.1884 Accuracy 0.1414
# Epoch 29 Batch 23350 Loss 0.1894 Accuracy 0.1416
# Epoch 29 Batch 23400 Loss 0.1912 Accuracy 0.1414
# Epoch 29 Batch 23450 Loss 0.1928 Accuracy 0.1413
# Epoch 29 Batch 23500 Loss 0.1943 Accuracy 0.1412
# Epoch 29 Batch 23550 Loss 0.1953 Accuracy 0.1408
# Epoch 29 Batch 23600 Loss 0.1972 Accuracy 0.1406
# Epoch 29 Batch 23650 Loss 0.1986 Accuracy 0.1406
# Epoch 29 Batch 23700 Loss 0.1998 Accuracy 0.1403
# Epoch 29 Batch 23750 Loss 0.2008 Accuracy 0.1401
# Epoch 29 Batch 23800 Loss 0.2017 Accuracy 0.1400
# Epoch 29 Batch 23850 Loss 0.2031 Accuracy 0.1398
# Epoch 29 Batch 23900 Loss 0.2036 Accuracy 0.1397
# Epoch 29 Batch 23950 Loss 0.2047 Accuracy 0.1396
# Epoch 29 Loss 0.2047 Accuracy 0.1396
# Time taken for 1 epoch: 65.73768305778503 secs
#
# Epoch 30 Batch 24000 Loss 0.1760 Accuracy 0.1429
# Epoch 30 Batch 24050 Loss 0.1799 Accuracy 0.1424
# Epoch 30 Batch 24100 Loss 0.1818 Accuracy 0.1420
# Epoch 30 Batch 24150 Loss 0.1840 Accuracy 0.1415
# Epoch 30 Batch 24200 Loss 0.1861 Accuracy 0.1412
# Epoch 30 Batch 24250 Loss 0.1887 Accuracy 0.1415
# Epoch 30 Batch 24300 Loss 0.1902 Accuracy 0.1412
# Epoch 30 Batch 24350 Loss 0.1914 Accuracy 0.1409
# Epoch 30 Batch 24400 Loss 0.1934 Accuracy 0.1408
# Epoch 30 Batch 24450 Loss 0.1953 Accuracy 0.1406
# Epoch 30 Batch 24500 Loss 0.1967 Accuracy 0.1404
# Epoch 30 Batch 24550 Loss 0.1980 Accuracy 0.1404
# Epoch 30 Batch 24600 Loss 0.1991 Accuracy 0.1404
# Epoch 30 Batch 24650 Loss 0.1998 Accuracy 0.1402
# Epoch 30 Batch 24700 Loss 0.2009 Accuracy 0.1401
# Epoch 30 Batch 24750 Loss 0.2018 Accuracy 0.1400
# Save checkpoints
# Epoch 30 Loss 0.2026 Accuracy 0.1399
# Time taken for 1 epoch: 67.61485171318054 secs
